# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import gurobipy as gb
from gurobipy import *
import math

# %% [markdown]
# ## Load Dataset

# %%
#load cardio dataset
Cardio = pd.read_excel("~/Downloads/Workout_data.xlsx")

#get index range for different activity types (Generic,Special,Muscle)
gen = Cardio[Cardio.GSM == 1]
G = len(gen)
index_g = G-1

spec = Cardio[Cardio.GSM == 0]
S= len(spec)
index_s = index_g+S

m = Cardio[Cardio.GSM == 2]
M = len(m)
index_m = index_s+M

# %% [markdown]
# ## User inputs

# %% [markdown]
# ##### User 1

# %%
#1. Choose target 
target = [1,1] #burn calories + muscle building

#2. advanced/beginner
a = 0

#3. weight
Current_weight=57

#4. Number of hours willing to workout per week
w_hours = 5

#5. how many calories user wants to burn per week
Calories = 1000

#6. days of the week preference
Days = [1,1,1,1,1,1,0]

#7. special Activities - day pref.
spec_days=[0,0,0,0,0,1,1]

#8. Category list (if special activity preference)
cat = ["Swimming"]

for i in range(D):
    if (Days[i] == 1 and spec_days[i] == 0):
        avail_days.append(1)
    else:
        avail_days.append(0)

#9.Muscle group preference
Muscle= ["Lower","Upper"]

#10.Muscle mass (in kg) user wants to gain
mm = 1

#if target is only muscle building
if (target[0]==0):
    Calories = 0

#calculate muscle mass gain per week (based on user level)
if (a == 1):
    pw = (Current_weight*(0.005/4))
else:
    pw = (Current_weight*(0.0125/4))

#calculate approximate number of weeks to repeat workout routine for muscle building
n_wks = mm/pw

# %% [markdown]
# ##### User 2

# %%
#1. Choose target 
target = [0,1] #build muscle

#2. advanced/beginner
a = 0

#3. weight
Current_weight=87

#4. Number of hours willing to workout per week
w_hours = 8

#5. how many calories user wants to burn per week
Calories = 0

#6. days of the week preference
Days = [1,1,1,1,1,1,0]

#7. special Activities - day pref.
spec_days=[0,0,0,1,1,1,0]

#8. Category list (if special activity preference)
cat = ["Tennis","Volleyball"]

for i in range(D):
    if (Days[i] == 1 and spec_days[i] == 0):
        avail_days.append(1)
    else:
        avail_days.append(0)

#9.Muscle group preference
Muscle= ["Lower","Core","Upper"]

#10.Muscle mass (in kg) user wants to gain
mm = 3

#if target is only muscle building
if (target[0]==0):
    Calories = 0

#calculate muscle mass gain per week (based on user level)
if (a == 1):
    pw = (Current_weight*(0.005/4))
else:
    pw = (Current_weight*(0.0125/4))

#calculate approximate number of weeks to repeat workout routine for muscle building
n_wks = mm/pw

# %% [markdown]
# ##### User 3

# %%
#1. Choose target 
target = [1,0] #burn calories

#2. advanced/beginner
a = 1

#3. weight
Current_weight=96

#4. Number of hours willing to workout per week
w_hours = 5

#5. how many calories user wants to burn per week
Calories = 3000

#6. days of the week preference
Days = [1,1,1,1,1,1,0]

#7. special Activities - day pref.
spec_days=[0,1,1,0,0,1,1]

#8. Category list (if special activity preference)
cat = []

for i in range(D):
    if (Days[i] == 1 and spec_days[i] == 0):
        avail_days.append(1)
    else:
        avail_days.append(0)

#9.Muscle group preference
Muscle= []

#10.Muscle mass (in kg) user wants to gain
mm = 0

#if target is only muscle building
if (target[0]==0):
    Calories = 0

#calculate muscle mass gain per week (based on user level)
if (a == 1):
    pw = (Current_weight*(0.005/4))
else:
    pw = (Current_weight*(0.0125/4))

#calculate approximate number of weeks to repeat workout routine for muscle building
n_wks = mm/pw

# %% [markdown]
# ## Pre-processing

# %%
import random
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

Cardio_Activities=Cardio['Activity, Exercise or Sport (1 hour)']
Week=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']

M = GRB.INFINITY
A=len(Cardio)
D=len(Week)

# Assign random general activities to be chosen (for a more assorted workout)
for i in range(0,G):
    Cardio['Order'][i] = random.randint(0,1)

#Initialise special/general activities picked
Cardio['User_picked'] = 0
        
#Get special activities based on category list
test_s = []
if (len(cat)!=0):
    for i in range(index_g+1,index_s+1):
        if (Cardio['Category'][i] in cat):
            Cardio.at[i,'User_picked'] = 1 #picked
            test_s.append(i)
        else:
            Cardio.at[i,'User_picked'] = 2 #not picked
else:
    for i in range(index_g+1,index_s+1):
        Cardio.at[i,'User_picked'] = 2 #not picked
            
#Get muscle activities based on Muscle list
test_m = []
if (len(cat)!=0):
    for j in range(index_s+1,A):
        c = Cardio.iloc[j]['Category']
        if c in Muscle:
            Cardio.at[j,'User_picked'] = 3 #picked
            test_m.append(j)
        else:
            Cardio.at[j,'User_picked'] = 4 #not picked
else:
    for j in range(index_s+1,A):
        Cardio.at[j,'User_picked'] = 4 #not picked

# %% [markdown]
# ## Model

# %%
model=gb.Model("Workout Plan")
    
#### Decision variables

T=model.addVars(D,A,lb=0,vtype=GRB.INTEGER,name=['T_'+i+'_'+j for i in Week for j in Cardio_Activities])# in 12 minute increments
Z=model.addVars(D,A,vtype=GRB.BINARY,name=['Z_'+i+'_'+j for i in Week for j in Cardio_Activities])
Y=model.addVars(D,A,vtype=GRB.BINARY,name=['Y_'+i+'_'+j for i in Week for j in Cardio_Activities])#dummy variable
X=model.addVars(D,A,vtype=GRB.BINARY,name=['X_'+i+'_'+j for i in Week for j in Cardio_Activities])#dummy variable
W=model.addVars(D,A,vtype=GRB.BINARY,name=['W_'+i+'_'+j for i in Week for j in Cardio_Activities])#dummy variable

#### Objective Function

model.setObjective(sum(T[i,j]*Z[i,j] for i in range(D) for j in range(A)),GRB.MINIMIZE)


#### Constraints

####Common Constraints (apply to both targets)---------------------------------------------------------
#1.1 work out time at most 1 hr per day
for i in range(D):
    model.addConstr(sum(T[i,j] for j in range(A)) <= 5)
    
#1.2 total number of calories: burnt 
model.addConstr(quicksum(T[i,j]*Cardio.iloc[j]["Calories per kg"]*Current_weight for i in range(D) for j in range(A))>=Calories)

#1.3 Workout hours 
model.addConstr(quicksum(T[i,j]*Z[i,j] for i in range(D) for j in range(A))<= w_hours*5)

#1.4 when X>0.01,Z=1,when X<0.01,Z=0,logical constraints
model.addConstrs(10000*Z[i,j]>=T[i,j]-0.01 for i in range(D)for j in range(A))
model.addConstrs(10000*(1-Z[i,j])>=0.01-T[i,j] for i in range(D)for j in range(A))

#1.5 No workout on the days user doesn't want
for i in range(D):
    if (Days[i]==0) and (spec_days[i]==0):
        model.addConstr(sum(Z[i,j] for j in range(A))==0)      
            
#1.6 advanced/beginner constraint
if (a == 1):
    model.addConstr(sum(T[i,j] for i in range(D) for j in Cardio.index[Cardio['Advanced'] == 0].tolist()) == 0)

if (a == 0):
    model.addConstr(sum(T[i,j] for i in range(D) for j in Cardio.index[Cardio['Advanced'] == 1].tolist()) == 0)

#1.7 choose only 1 of special activities
test_s.sort()
if (len(test_s) > 0):
    model.addConstr(sum(Z[i,test_s[x]] for i in range(D) for x in range(len(test_s))) == 1)
    
#1.8 Time constraint for special activity    
if (len(test_s) > 0):
    model.addConstr(sum(T[i,test_s[x]] for i in range(D) for x in range(len(test_s))) == 5)
        
#1.9 no other activities on special activity day        
for i in range(D):
    model.addConstrs(sum(T[i,j] for j in Cardio.index[Cardio['GSM'] == 0].tolist()) <= M*Y[i,j] for j in range(A))
    model.addConstrs(sum(T[i,j] for j in Cardio.index[Cardio['GSM'] != 0].tolist()) <= M*(1-Y[i,j]) for j in range(A))      
        
#1.10 No special activity on normal days
for i in range(D):
    if (spec_days[i]==0):
        model.addConstr(sum(T[i,j] for j in Cardio.index[Cardio['User_picked'] == 1].tolist())==0)

        
####Calorie target Constraints--------------------------------------------------
if (target[0]==1):
    
#2.1 Do not pick from muscle building activities
    if (target[1] == 0):
        for j in range(index_s+1,A):
            model.addConstr(sum(T[i,j] for i in range(D))==0)

#2.2 do not select generic activities where Order = 0 (randomization)
    for j in range(0,G):
         if (Cardio.iloc[j]["Order"] == 0):
                model.addConstr(sum(T[i,j] for i in range(D)) == 0)
                   
#2.3 activities not selected by user should not be picked
    for j in range(A):
        if (Cardio.iloc[j]["User_picked"] == 2):
            model.addConstr(sum(T[i,j] for i in range(D))==0)
            
            
#2.4 each exercise per day should not exceed 24 mins - GENERIC
    for j in range(0,G):
        model.addConstr(sum(T[i,j] for i in range(D))<=2)

        
####Muscle Building Constraints-------------------------------------------------
if (target[1]==1):
    
#3.1 Muscle mass weekly gain constraint
    model.addConstr(quicksum(T[i,j]*Cardio.iloc[j]["Muscle_Mass"]*Current_weight for i in range(D) for j in range(A)) >= pw) 
            
#3.2 Muscle training group not selected by user must not be picked
    for j in range(A):
        if (Cardio.iloc[j]["User_picked"] == 4):
            model.addConstr(sum(T[i,j] for i in range(D))==0)
            
#3.3 Select muscle building exercise + time constraints  
    model.addConstr(sum(T[i,j] for i in range(D) for j in test_m) >= 15) 
    
#3.4 each exercise should be at most 12 mins
    for i in range(D):
        for j in range(index_s+1,A):
            model.addConstr(T[i,j] <= 1)
                        
#3.5 Have at least one activity from each muscle group
    if ("Upper" in Muscle):
        model.addConstr(sum(Z[i,j] for i in range(D) for j in Cardio.index[Cardio['Category'] == 'Upper'].tolist()) >=
                      0.2*sum(Z[i,j] for i in range(D) for j in range(A)))
                        
    if ("Lower" in Muscle):
        model.addConstr(sum(Z[i,j] for i in range(D) for j in Cardio.index[Cardio['Category'] == 'Lower'].tolist()) >=
                       0.2*sum(Z[i,j] for i in range(D) for j in range(A)))
        
    if ("Core" in Muscle and a == 0):
        model.addConstr(sum(Z[i,j] for i in range(D) for j in Cardio.index[Cardio['Category'] == 'Core'].tolist()) >=
                        4)
        
#3.6 if target both, ensure at least one workout for cardio
    if target[0] == 1:
        for i in range (D):
            if (avail_days[i] == 1):
                model.addConstrs(sum(Z[i,j] for j in range(A)) -0.01  <= M*(1-W[i,j]) for j in range (A))
                model.addConstrs(-sum(Z[i,j] for j in range (G)) + 0.01  <= M*W[i,j] for j in range (G))       

model.Params.LogToConsole = 0

model.optimize()

#print objective value
print("Amount of time to workout per week is:", model.objVal/5, " hrs")

#print number of weeks to repeat plan (where applicable)
if (target[1]==1):
    print("Repeat muscle workout plan for around ", math.ceil(n_wks), " weeks")
    
for v in model.getVars():
    if v.x>0:
        print(v.varName,'=',v.x)
# Out:
# Amount of time to workout per week is: 4.4  hrs
# Repeat muscle workout plan for around  6  weeks
# T_Monday_Bent-Over Dumbbell Row = 1.0
# T_Monday_Single-Arm Barbell Curl = 1.0
# T_Monday_Push-Up = 1.0
# T_Monday_Elevated Hip Lift = 1.0
# T_Monday_Dumbbell Lunge = 1.0
# T_Tuesday_One Arm Dumbbell Row = 1.0
# T_Tuesday_Step-Up = 1.0
# T_Wednesday_Pull-Up = 1.0
# T_Wednesday_One Arm Dumbbell Row = 1.0
# T_Wednesday_Single-Arm Barbell Curl = 1.0
# T_Wednesday_Dumbbell Lunge = 1.0
# T_Wednesday_Step-Up = 1.0
# T_Thursday_Bent-Over Dumbbell Row = 1.0
# T_Friday_Close-Grip Lat Pulldown = 1.0
# T_Friday_One Arm Dumbbell Row = 1.0
# T_Friday_Elevated Hip Lift = 1.0
# T_Saturday_Lying Machine Squat = 1.0
# T_Sunday_Swimming, slow = 5.0
# Z_Monday_Bent-Over Dumbbell Row = 1.0
# Z_Monday_Single-Arm Barbell Curl = 1.0
# Z_Monday_Push-Up = 1.0
# Z_Monday_Elevated Hip Lift = 1.0
# Z_Monday_Dumbbell Lunge = 1.0
# Z_Tuesday_One Arm Dumbbell Row = 1.0
# Z_Tuesday_Step-Up = 1.0
# Z_Wednesday_Pull-Up = 1.0
# Z_Wednesday_One Arm Dumbbell Row = 1.0
# Z_Wednesday_Single-Arm Barbell Curl = 1.0
# Z_Wednesday_Dumbbell Lunge = 1.0
# Z_Wednesday_Step-Up = 1.0
# Z_Thursday_Bent-Over Dumbbell Row = 1.0
# Z_Friday_Close-Grip Lat Pulldown = 1.0
# Z_Friday_One Arm Dumbbell Row = 1.0
# Z_Friday_Elevated Hip Lift = 1.0
# Z_Saturday_Lying Machine Squat = 1.0
# Z_Sunday_Swimming, slow = 1.0
# Y_Monday_Race walking = 1.0
# Y_Monday_Walking, under 2.0 mph, very slow = 1.0
# Y_Monday_Walking 2.0 mph, slow = 1.0
# Y_Monday_Walking 2.5 mph = 1.0
# Y_Monday_Walking 3.0 mph, moderate = 1.0
# Y_Monday_Walking 3.5 mph, brisk pace = 1.0
# Y_Monday_Walking 3.5 mph, uphill = 1.0
# Y_Monday_Walking 4.0 mph, very brisk = 1.0
# Y_Monday_Walking 4.5 mph = 1.0
# Y_Monday_Walking 5.0 mph = 1.0
# Y_Monday_Stretching, hatha yoga = 1.0
# Y_Monday_Mild stretching = 1.0
# Y_Monday_Stair machine = 1.0
# Y_Monday_Running, 5 mph (12 minute mile) = 1.0
# Y_Monday_Running, 5.2 mph (11.5 minute mile) = 1.0
# Y_Monday_Running, 6 mph (10 min mile) = 1.0
# Y_Monday_Running, 6.7 mph (9 min mile) = 1.0
# Y_Monday_Running, 7 mph (8.5 min mile) = 1.0
# Y_Monday_Running, 7.5mph (8 min mile) = 1.0
# Y_Monday_Running, 8 mph (7.5 min mile) = 1.0
# Y_Monday_Running, 8.6 mph (7 min mile) = 1.0
# Y_Monday_Running, general = 1.0
# Y_Monday_Jumping rope, fast = 1.0
# Y_Monday_Jumping rope, moderate = 1.0
# Y_Monday_Jumping rope, slow = 1.0
# Y_Monday_Cycling, mountain bike, bmx = 1.0
# Y_Monday_Cycling, <10 mph, leisure bicycling = 1.0
# Y_Monday_Cycling, 10-11.9 mph, light = 1.0
# Y_Monday_Cycling, 12-13.9 mph, moderate = 1.0
# Y_Monday_Cycling, 14-15.9 mph, vigorous = 1.0
# Y_Monday_Cycling, 16-19 mph, very fast, racing = 1.0
# Y_Monday_Stationary cycling, very light = 1.0
# Y_Monday_Stationary cycling, light = 1.0
# Y_Monday_Stationary cycling, moderate = 1.0
# Y_Monday_Stationary cycling, vigorous = 1.0
# Y_Monday_Stationary cycling, very vigorous = 1.0
# Y_Monday_Circuit training, minimal rest = 1.0
# Y_Monday_Aerobics, low impact = 1.0
# Y_Monday_Aerobics, high impact = 1.0
# Y_Monday_Aerobics, step aerobics = 1.0
# Y_Monday_Aerobics, general = 1.0
# Y_Monday_Rock climbing, mountain climbing = 1.0
# Y_Monday_Playing volleyball = 1.0
# Y_Monday_Volleyball, beach = 1.0
# Y_Monday_Playing tennis = 1.0
# Y_Monday_Tennis, doubles = 1.0
# Y_Monday_Tennis, singles = 1.0
# Y_Monday_Swimming, fast = 1.0
# Y_Monday_Swimming, slow = 1.0
# Y_Monday_Squash = 1.0
# Y_Monday_Softball or baseball = 1.0
# Y_Monday_Skiing, water skiing = 1.0
# Y_Monday_Ski mobiling = 1.0
# Y_Monday_Skin diving, moderate = 1.0
# Y_Monday_Skin diving, scuba diving = 1.0
# Y_Monday_Roller skating = 1.0
# Y_Monday_Roller blading, in-line skating = 1.0
# Y_Monday_Ice skating, average speed = 1.0
# Y_Monday_Ice skating, rapidly = 1.0
# Y_Monday_Skateboarding = 1.0
# Y_Monday_Soccer = 1.0
# Y_Monday_Juggling = 1.0
# Y_Monday_Rugby = 1.0
# Y_Monday_Playing paddleball = 1.0
# Y_Monday_Riding a horse, general = 1.0
# Y_Monday_Hockey, field hockey = 1.0
# Y_Monday_Hockey, ice hockey = 1.0
# Y_Monday_Handball = 1.0
# Y_Monday_Handball, team = 1.0
# Y_Monday_Frisbee playing, general = 1.0
# Y_Monday_Frisbee, ultimate frisbee = 1.0
# Y_Monday_Football, touch, flag, general = 1.0
# Y_Monday_Football or baseball, playing catch = 1.0
# Y_Monday_Ballet, twist, jazz, tap = 1.0
# Y_Monday_Ballroom dancing, slow = 1.0
# Y_Monday_Ballroom dancing, fast = 1.0
# Y_Monday_Rock climbing, ascending rock = 1.0
# Y_Monday_Rock climbing, rappelling = 1.0
# Y_Monday_Boxing, punching bag = 1.0
# Y_Monday_Boxing, sparring = 1.0
# Y_Monday_Bowling = 1.0
# Y_Monday_Playing basketball, non game = 1.0
# Y_Monday_Basketball, shooting baskets = 1.0
# Y_Monday_Badminton = 1.0
# Y_Monday_Archery = 1.0
# Y_Monday_Water aerobics = 1.0
# Y_Monday_Full Reverse Crunch - Lower = 1.0
# Y_Monday_Full Reverse Crunch - Obliques = 1.0
# Y_Monday_Full Reverse Crunch - Total = 1.0
# Y_Monday_Full Reverse Crunch - Upper = 1.0
# Y_Monday_Full Reverse Crunch = 1.0
# Y_Monday_Close-Grip Lat Pulldown = 1.0
# Y_Monday_Inverted Pull-Up = 1.0
# Y_Monday_Lat Pulldown = 1.0
# Y_Monday_Pull-Up = 1.0
# Y_Monday_Reverse-Grip Lat Pullown = 1.0
# Y_Monday_Reverse-Grip Pull-Up = 1.0
# Y_Monday_V-Bar Pull-Up = 1.0
# Y_Monday_Wide-Grip Lat Pulldown = 1.0
# Y_Monday_Bent-Over Alternating Dumbbell Row = 1.0
# Y_Monday_Bent-Over Barbell Row = 1.0
# Y_Monday_Bent-Over Dumbbell Row = 1.0
# Y_Monday_Bent-Over Hammer Dumbbell Row = 1.0
# Y_Monday_Bent-Over Long Barbell Row = 1.0
# Y_Monday_Bent-Over Reverse-Grip Barbell Row = 1.0
# Y_Monday_Bent-Over Single-Arm Long Barbell Row = 1.0
# Y_Monday_Machine Row = 1.0
# Y_Monday_One Arm Dumbbell Row = 1.0
# Y_Monday_Reverse Incline Dumbbell Row = 1.0
# Y_Monday_Rope Cable Row = 1.0
# Y_Monday_Seated Cable Row = 1.0
# Y_Monday_Seated Row = 1.0
# Y_Monday_Single-Arm Cable Row = 1.0
# Y_Monday_Single-Arm Dumbbell Row = 1.0
# Y_Monday_Single-Arm Lat Pulldown = 1.0
# Y_Monday_Standing Cable Row = 1.0
# Y_Monday_Standing Single-Arm Cable Row = 1.0
# Y_Monday_Alternating Dumbbell Curl = 1.0
# Y_Monday_Alternating Hammer Curl = 1.0
# Y_Monday_Barbell Curl = 1.0
# Y_Monday_Bicep Curl = 1.0
# Y_Monday_Bottom/Top/Full Curls = 1.0
# Y_Monday_Cable Curl = 1.0
# Y_Monday_Concentration Dumbbell Curl = 1.0
# Y_Monday_Cross Body Hammer Curl = 1.0
# Y_Monday_Dumbbell Curl = 1.0
# Y_Monday_EZ-Bar Curl = 1.0
# Y_Monday_Hammer Curl = 1.0
# Y_Monday_Incline Alternating Dumbbell Curl = 1.0
# Y_Monday_Incline Alternating Hammer Curl = 1.0
# Y_Monday_Incline Dumbbell Curl = 1.0
# Y_Monday_Incline Hammer Curl = 1.0
# Y_Monday_Kneeling Cable Curl = 1.0
# Y_Monday_Lying Cable Curl = 1.0
# Y_Monday_Lying Double Biceps Cable Curl = 1.0
# Y_Monday_Lying High Cable Curl = 1.0
# Y_Monday_Machine Curl = 1.0
# Y_Monday_Overhead Double Biceps Cable Curl = 1.0
# Y_Monday_Overhead Rope Cable Curl = 1.0
# Y_Monday_Preacher Barbell Curl = 1.0
# Y_Monday_Preacher Cable Curl = 1.0
# Y_Monday_Preacher Dumbbell Curl = 1.0
# Y_Monday_Preacher EZ-Bar Curl = 1.0
# Y_Monday_Preacher Hammer Dumbbell Curl = 1.0
# Y_Monday_Preacher Single-Arm Dumbbell Curl = 1.0
# Y_Monday_Reverse Curl = 1.0
# Y_Monday_Rope Cable Curl = 1.0
# Y_Monday_Seated Alternating Curl = 1.0
# Y_Monday_Seated Alternating Hammer Curl = 1.0
# Y_Monday_Seated Dumbbell Curl = 1.0
# Y_Monday_Seated Hammer Curl = 1.0
# Y_Monday_Single-Arm Barbell Curl = 1.0
# Y_Monday_Single-Arm Cable Curl = 1.0
# Y_Monday_Single-Arm Dumbbell Curl w/ Incline Bench = 1.0
# Y_Monday_Spider Curl = 1.0
# Y_Monday_Barbell Calf Raise = 1.0
# Y_Monday_Calf Press = 1.0
# Y_Monday_Calf Raise - Seated = 1.0
# Y_Monday_Calf Raise - Standing = 1.0
# Y_Monday_Dumbbell Calf Raise = 1.0
# Y_Monday_Single-Leg Calf Press = 1.0
# Y_Monday_Single-Leg Dumbbell Calf Raise = 1.0
# Y_Monday_Smith Machine Calf Raise = 1.0
# Y_Monday_Seated Calf Raise = 1.0
# Y_Monday_Seated Single-Leg Calf Raise = 1.0
# Y_Monday_Alternating Dumbbell Bench Press = 1.0
# Y_Monday_Barbell Bench Press = 1.0
# Y_Monday_Chest Press = 1.0
# Y_Monday_Decline Dumbbell Bench Press = 1.0
# Y_Monday_Decline Smith Machine Bench Press = 1.0
# Y_Monday_Dumbbell Bench Press = 1.0
# Y_Monday_Dumbbell Push-Up = 1.0
# Y_Monday_Elevated Push-Up = 1.0
# Y_Monday_Flat Bench Press = 1.0
# Y_Monday_Incline Alternating Dumbbell Bench Press = 1.0
# Y_Monday_Incline Barbell Bench Press = 1.0
# Y_Monday_Incline Bench Press = 1.0
# Y_Monday_Incline Dumbbell Bench Press = 1.0
# Y_Monday_Incline Hammer Dumbbell Bench Press = 1.0
# Y_Monday_Incline Single-Arm Dumbbell Bench Press = 1.0
# Y_Monday_Incline Smith Machine Bench Press = 1.0
# Y_Monday_Incline Twisting Dumbbell Bench Press = 1.0
# Y_Monday_Kneeling Push-Up = 1.0
# Y_Monday_Machine Bench Press = 1.0
# Y_Monday_Machine Vertical Bench Press = 1.0
# Y_Monday_Medicine Ball Crossover Push-Up = 1.0
# Y_Monday_Push-Up = 1.0
# Y_Monday_Single-Arm Dumbbell Bench Press = 1.0
# Y_Monday_Smith Machine Bench Press = 1.0
# Y_Monday_Twisting Dumbbell Bench Press = 1.0
# Y_Monday_Wide-Grip Push-Up = 1.0
# Y_Monday_Cable Crossover = 1.0
# Y_Monday_Cable Fly = 1.0
# Y_Monday_Decline Dumbbell Fly = 1.0
# Y_Monday_Dumbbell Fly = 1.0
# Y_Monday_High Cable Crossover = 1.0
# Y_Monday_Incline Cable Fly = 1.0
# Y_Monday_Incline Dumbbell Fly = 1.0
# Y_Monday_Incline Twisting Dumbbell Fly = 1.0
# Y_Monday_Low Cable Crossover = 1.0
# Y_Monday_Pec Deck = 1.0
# Y_Monday_Pec Deck Fly = 1.0
# Y_Monday_Bent-Knee Single-Leg Hip Lift = 1.0
# Y_Monday_Elevated Hip Lift = 1.0
# Y_Monday_Elevated Single-Leg Hip Lift = 1.0
# Y_Monday_Hip Lift = 1.0
# Y_Monday_Single-Leg Hip Lift = 1.0
# Y_Monday_Deadlift = 1.0
# Y_Monday_Leg Curl = 1.0
# Y_Monday_Lying Alternating Leg Curl = 1.0
# Y_Monday_Lying Leg Curl = 1.0
# Y_Monday_Lying Single-Leg Curl = 1.0
# Y_Monday_Seated Leg Curl = 1.0
# Y_Monday_Barbell Diagonal Lunge = 1.0
# Y_Monday_Barbell Hack Squat = 1.0
# Y_Monday_Barbell Lunge = 1.0
# Y_Monday_Barbell Reverse Lunge = 1.0
# Y_Monday_Barbell Side Lunge = 1.0
# Y_Monday_Barbell Split Squat = 1.0
# Y_Monday_Barbell Squat = 1.0
# Y_Monday_Barbell Step-Up = 1.0
# Y_Monday_Barbell Walking Lunge = 1.0
# Y_Monday_Diagonal Lunge = 1.0
# Y_Monday_Dumbbell Diagonal Lunge = 1.0
# Y_Monday_Dumbbell Lunge = 1.0
# Y_Monday_Dumbbell Reverse Lunge = 1.0
# Y_Monday_Dumbbell Side Lunge = 1.0
# Y_Monday_Dumbbell Split Squat = 1.0
# Y_Monday_Dumbbell Squat = 1.0
# Y_Monday_Dumbbell Step-Up = 1.0
# Y_Monday_Dumbbell Walking Lunge = 1.0
# Y_Monday_Forward Lunge = 1.0
# Y_Monday_Lateral Barbell Squat = 1.0
# Y_Monday_Lateral Barbell Step-Up = 1.0
# Y_Monday_Lateral Squat = 1.0
# Y_Monday_Lateral Step-Up = 1.0
# Y_Monday_Leg Press = 1.0
# Y_Monday_Lunge = 1.0
# Y_Monday_Lying Machine Squat = 1.0
# Y_Monday_Machine Hack Squat = 1.0
# Y_Monday_Reverse Lunge = 1.0
# Y_Monday_Single-Arm Barbell Side Squat = 1.0
# Y_Monday_Single-Arm Dumbbell Side Squat = 1.0
# Y_Monday_Single-Leg Barbell Squat = 1.0
# Y_Monday_Single-Leg Box Squat = 1.0
# Y_Monday_Single-Leg Dumbbell Box Squat = 1.0
# Y_Monday_Single-Leg Dumbbell Squat = 1.0
# Y_Monday_Single-Leg Squat = 1.0
# Y_Monday_Smith Machine Squat = 1.0
# Y_Monday_Split Squat = 1.0
# Y_Monday_Step-Up = 1.0
# Y_Monday_Walking Lunge = 1.0
# Y_Monday_Alternating Leg Extension = 1.0
# Y_Monday_Leg Extension = 1.0
# Y_Monday_Single-Leg Extension = 1.0
# Y_Monday_Alternating Superman = 1.0
# Y_Monday_Back Raise = 1.0
# Y_Monday_Quadruped Alternating Superman = 1.0
# Y_Monday_Superman = 1.0
# Y_Monday_Superman Hold = 1.0
# Y_Monday_Arnold Dumbbell Press = 1.0
# Y_Monday_Barbell Shoulder Press = 1.0
# Y_Monday_Dumbbell Alternating Shoulder Press = 1.0
# Y_Monday_Dumbbell Front Raise = 1.0
# Y_Monday_Dumbbell Shoulder Press = 1.0
# Y_Monday_Dumbbell Twisting Shoulder Press = 1.0
# Y_Monday_Machine Shoulder Press = 1.0
# Y_Monday_Seated Dumbbell Rear Delt Elbow Raise = 1.0
# Y_Monday_Single-Arm Dumbbell Shoulder Press = 1.0
# Y_Monday_Smith Machine Shoulder Press = 1.0
# Y_Monday_Barbell Front Raise = 1.0
# Y_Monday_Bent-Over Cable Rear Delt Raise = 1.0
# Y_Monday_Bent-Over Dumbbell Rear Delt Raise = 1.0
# Y_Monday_Cable Front Raise = 1.0
# Y_Monday_Cable Lateral Raise = 1.0
# Y_Monday_Dumbbell Lateral Raise = 1.0
# Y_Monday_Front Plate Raise = 1.0
# Y_Monday_Kneeling Single-Arm Cable Rear Delt Raise = 1.0
# Y_Monday_Lying Dumbbell External Rotation = 1.0
# Y_Monday_Lying Dumbbell Rear Delt Raise = 1.0
# Y_Monday_Lying Single-Arm Dumbbell Rear Delt Raise = 1.0
# Y_Monday_Pec Deck Real Delt Extensions = 1.0
# Y_Monday_Reverse Incline Dumbbell Rear Delt Raise = 1.0
# Y_Monday_Seated Dumbbell Rear Delt Raise = 1.0
# Y_Monday_Single-Arm Cable Lateral Raise = 1.0
# Y_Monday_Cable External Rotation = 1.0
# Y_Monday_Close-Grip Bench Press = 1.0
# Y_Monday_Forward Lean Dips = 1.0
# Y_Monday_Assisted Dips = 1.0
# Y_Monday_Bench Dips = 1.0
# Y_Monday_Diamond Push-Up = 1.0
# Y_Monday_Dips = 1.0
# Y_Monday_Machine Dips = 1.0
# Y_Monday_Decline Dumbbell Triceps Extension = 1.0
# Y_Monday_Decline EZ-Bar Tricep Extension = 1.0
# Y_Monday_Decline Single Dumbbell Triceps Extension = 1.0
# Y_Monday_Decline Single-Arm Dumbbell Triceps Extension = 1.0
# Y_Monday_Dumbbell Kickback = 1.0
# Y_Monday_Incline EZ-Bar Tricep Extension = 1.0
# Y_Monday_Kneeling Cable Triceps Extension = 1.0
# Y_Monday_Leaning Overhead Tricep Extension = 1.0
# Y_Monday_Low Cable Triceps Extension = 1.0
# Y_Monday_Lying Cable Triceps Extension = 1.0
# Y_Monday_Lying EZ-Bar Triceps Extension = 1.0
# Y_Monday_Lying Overhead EZ-Bar Tricep Extension = 1.0
# Y_Monday_Lying Reverse EZ-Bar Triceps Extension = 1.0
# Y_Monday_Lying Single Dumbbell Triceps Extension = 1.0
# Y_Monday_Lying Single-Arm Dumbbell Triceps Extension = 1.0
# Y_Monday_Lying Tricep Extensions = 1.0
# Y_Monday_Overhead Dumbbell Triceps Extension = 1.0
# Y_Monday_Overhead EZ-Bar Triceps Extension = 1.0
# Y_Monday_Overhead Rope Cable Tricep Extension = 1.0
# Y_Monday_Overhead Single Dumbbell Tricep Extension = 1.0
# Y_Monday_Overhead Single-Arm Cable Tricep Extension = 1.0
# Y_Monday_Overhead Single-Arm Dumbbell Tricep Extension = 1.0
# Y_Monday_Reverse Tricep Pushdown = 1.0
# Y_Monday_Rope Triceps Pushdown = 1.0
# Y_Monday_Single-Arm Towel Triceps Pushdown = 1.0
# Y_Monday_Single-Arm Triceps Pushdown = 1.0
# Y_Monday_Towel Triceps Pushdown = 1.0
# Y_Monday_Tricep Extensions = 1.0
# Y_Monday_Tricep Pushdown = 1.0
# Y_Monday_Tricep Pushdown = 1.0
# Y_Monday_V-Bar Tricep Pushdown = 1.0
# Y_Tuesday_Race walking = 1.0
# Y_Tuesday_Walking, under 2.0 mph, very slow = 1.0
# Y_Tuesday_Walking 2.0 mph, slow = 1.0
# Y_Tuesday_Walking 2.5 mph = 1.0
# Y_Tuesday_Walking 3.0 mph, moderate = 1.0
# Y_Tuesday_Walking 3.5 mph, brisk pace = 1.0
# Y_Tuesday_Walking 3.5 mph, uphill = 1.0
# Y_Tuesday_Walking 4.0 mph, very brisk = 1.0
# Y_Tuesday_Walking 4.5 mph = 1.0
# Y_Tuesday_Walking 5.0 mph = 1.0
# Y_Tuesday_Stretching, hatha yoga = 1.0
# Y_Tuesday_Mild stretching = 1.0
# Y_Tuesday_Stair machine = 1.0
# Y_Tuesday_Running, 5 mph (12 minute mile) = 1.0
# Y_Tuesday_Running, 5.2 mph (11.5 minute mile) = 1.0
# Y_Tuesday_Running, 6 mph (10 min mile) = 1.0
# Y_Tuesday_Running, 6.7 mph (9 min mile) = 1.0
# Y_Tuesday_Running, 7 mph (8.5 min mile) = 1.0
# Y_Tuesday_Running, 7.5mph (8 min mile) = 1.0
# Y_Tuesday_Running, 8 mph (7.5 min mile) = 1.0
# Y_Tuesday_Running, 8.6 mph (7 min mile) = 1.0
# Y_Tuesday_Running, general = 1.0
# Y_Tuesday_Jumping rope, fast = 1.0
# Y_Tuesday_Jumping rope, moderate = 1.0
# Y_Tuesday_Jumping rope, slow = 1.0
# Y_Tuesday_Cycling, mountain bike, bmx = 1.0
# Y_Tuesday_Cycling, <10 mph, leisure bicycling = 1.0
# Y_Tuesday_Cycling, 10-11.9 mph, light = 1.0
# Y_Tuesday_Cycling, 12-13.9 mph, moderate = 1.0
# Y_Tuesday_Cycling, 14-15.9 mph, vigorous = 1.0
# Y_Tuesday_Cycling, 16-19 mph, very fast, racing = 1.0
# Y_Tuesday_Stationary cycling, very light = 1.0
# Y_Tuesday_Stationary cycling, light = 1.0
# Y_Tuesday_Stationary cycling, moderate = 1.0
# Y_Tuesday_Stationary cycling, vigorous = 1.0
# Y_Tuesday_Stationary cycling, very vigorous = 1.0
# Y_Tuesday_Circuit training, minimal rest = 1.0
# Y_Tuesday_Aerobics, low impact = 1.0
# Y_Tuesday_Aerobics, high impact = 1.0
# Y_Tuesday_Aerobics, step aerobics = 1.0
# Y_Tuesday_Aerobics, general = 1.0
# Y_Tuesday_Rock climbing, mountain climbing = 1.0
# Y_Tuesday_Playing volleyball = 1.0
# Y_Tuesday_Volleyball, beach = 1.0
# Y_Tuesday_Playing tennis = 1.0
# Y_Tuesday_Tennis, doubles = 1.0
# Y_Tuesday_Tennis, singles = 1.0
# Y_Tuesday_Swimming, fast = 1.0
# Y_Tuesday_Swimming, slow = 1.0
# Y_Tuesday_Squash = 1.0
# Y_Tuesday_Softball or baseball = 1.0
# Y_Tuesday_Skiing, water skiing = 1.0
# Y_Tuesday_Ski mobiling = 1.0
# Y_Tuesday_Skin diving, moderate = 1.0
# Y_Tuesday_Skin diving, scuba diving = 1.0
# Y_Tuesday_Roller skating = 1.0
# Y_Tuesday_Roller blading, in-line skating = 1.0
# Y_Tuesday_Ice skating, average speed = 1.0
# Y_Tuesday_Ice skating, rapidly = 1.0
# Y_Tuesday_Skateboarding = 1.0
# Y_Tuesday_Soccer = 1.0
# Y_Tuesday_Juggling = 1.0
# Y_Tuesday_Rugby = 1.0
# Y_Tuesday_Playing paddleball = 1.0
# Y_Tuesday_Riding a horse, general = 1.0
# Y_Tuesday_Hockey, field hockey = 1.0
# Y_Tuesday_Hockey, ice hockey = 1.0
# Y_Tuesday_Handball = 1.0
# Y_Tuesday_Handball, team = 1.0
# Y_Tuesday_Frisbee playing, general = 1.0
# Y_Tuesday_Frisbee, ultimate frisbee = 1.0
# Y_Tuesday_Football, touch, flag, general = 1.0
# Y_Tuesday_Football or baseball, playing catch = 1.0
# Y_Tuesday_Ballet, twist, jazz, tap = 1.0
# Y_Tuesday_Ballroom dancing, slow = 1.0
# Y_Tuesday_Ballroom dancing, fast = 1.0
# Y_Tuesday_Rock climbing, ascending rock = 1.0
# Y_Tuesday_Rock climbing, rappelling = 1.0
# Y_Tuesday_Boxing, punching bag = 1.0
# Y_Tuesday_Boxing, sparring = 1.0
# Y_Tuesday_Bowling = 1.0
# Y_Tuesday_Playing basketball, non game = 1.0
# Y_Tuesday_Basketball, shooting baskets = 1.0
# Y_Tuesday_Badminton = 1.0
# Y_Tuesday_Archery = 1.0
# Y_Tuesday_Water aerobics = 1.0
# Y_Tuesday_Full Reverse Crunch - Lower = 1.0
# Y_Tuesday_Full Reverse Crunch - Obliques = 1.0
# Y_Tuesday_Full Reverse Crunch - Total = 1.0
# Y_Tuesday_Full Reverse Crunch - Upper = 1.0
# Y_Tuesday_Full Reverse Crunch = 1.0
# Y_Tuesday_Close-Grip Lat Pulldown = 1.0
# Y_Tuesday_Inverted Pull-Up = 1.0
# Y_Tuesday_Lat Pulldown = 1.0
# Y_Tuesday_Pull-Up = 1.0
# Y_Tuesday_Reverse-Grip Lat Pullown = 1.0
# Y_Tuesday_Reverse-Grip Pull-Up = 1.0
# Y_Tuesday_V-Bar Pull-Up = 1.0
# Y_Tuesday_Wide-Grip Lat Pulldown = 1.0
# Y_Tuesday_Bent-Over Alternating Dumbbell Row = 1.0
# Y_Tuesday_Bent-Over Barbell Row = 1.0
# Y_Tuesday_Bent-Over Dumbbell Row = 1.0
# Y_Tuesday_Bent-Over Hammer Dumbbell Row = 1.0
# Y_Tuesday_Bent-Over Long Barbell Row = 1.0
# Y_Tuesday_Bent-Over Reverse-Grip Barbell Row = 1.0
# Y_Tuesday_Bent-Over Single-Arm Long Barbell Row = 1.0
# Y_Tuesday_Machine Row = 1.0
# Y_Tuesday_One Arm Dumbbell Row = 1.0
# Y_Tuesday_Reverse Incline Dumbbell Row = 1.0
# Y_Tuesday_Rope Cable Row = 1.0
# Y_Tuesday_Seated Cable Row = 1.0
# Y_Tuesday_Seated Row = 1.0
# Y_Tuesday_Single-Arm Cable Row = 1.0
# Y_Tuesday_Single-Arm Dumbbell Row = 1.0
# Y_Tuesday_Single-Arm Lat Pulldown = 1.0
# Y_Tuesday_Standing Cable Row = 1.0
# Y_Tuesday_Standing Single-Arm Cable Row = 1.0
# Y_Tuesday_Alternating Dumbbell Curl = 1.0
# Y_Tuesday_Alternating Hammer Curl = 1.0
# Y_Tuesday_Barbell Curl = 1.0
# Y_Tuesday_Bicep Curl = 1.0
# Y_Tuesday_Bottom/Top/Full Curls = 1.0
# Y_Tuesday_Cable Curl = 1.0
# Y_Tuesday_Concentration Dumbbell Curl = 1.0
# Y_Tuesday_Cross Body Hammer Curl = 1.0
# Y_Tuesday_Dumbbell Curl = 1.0
# Y_Tuesday_EZ-Bar Curl = 1.0
# Y_Tuesday_Hammer Curl = 1.0
# Y_Tuesday_Incline Alternating Dumbbell Curl = 1.0
# Y_Tuesday_Incline Alternating Hammer Curl = 1.0
# Y_Tuesday_Incline Dumbbell Curl = 1.0
# Y_Tuesday_Incline Hammer Curl = 1.0
# Y_Tuesday_Kneeling Cable Curl = 1.0
# Y_Tuesday_Lying Cable Curl = 1.0
# Y_Tuesday_Lying Double Biceps Cable Curl = 1.0
# Y_Tuesday_Lying High Cable Curl = 1.0
# Y_Tuesday_Machine Curl = 1.0
# Y_Tuesday_Overhead Double Biceps Cable Curl = 1.0
# Y_Tuesday_Overhead Rope Cable Curl = 1.0
# Y_Tuesday_Preacher Barbell Curl = 1.0
# Y_Tuesday_Preacher Cable Curl = 1.0
# Y_Tuesday_Preacher Dumbbell Curl = 1.0
# Y_Tuesday_Preacher EZ-Bar Curl = 1.0
# Y_Tuesday_Preacher Hammer Dumbbell Curl = 1.0
# Y_Tuesday_Preacher Single-Arm Dumbbell Curl = 1.0
# Y_Tuesday_Reverse Curl = 1.0
# Y_Tuesday_Rope Cable Curl = 1.0
# Y_Tuesday_Seated Alternating Curl = 1.0
# Y_Tuesday_Seated Alternating Hammer Curl = 1.0
# Y_Tuesday_Seated Dumbbell Curl = 1.0
# Y_Tuesday_Seated Hammer Curl = 1.0
# Y_Tuesday_Single-Arm Barbell Curl = 1.0
# Y_Tuesday_Single-Arm Cable Curl = 1.0
# Y_Tuesday_Single-Arm Dumbbell Curl w/ Incline Bench = 1.0
# Y_Tuesday_Spider Curl = 1.0
# Y_Tuesday_Barbell Calf Raise = 1.0
# Y_Tuesday_Calf Press = 1.0
# Y_Tuesday_Calf Raise - Seated = 1.0
# Y_Tuesday_Calf Raise - Standing = 1.0
# Y_Tuesday_Dumbbell Calf Raise = 1.0
# Y_Tuesday_Single-Leg Calf Press = 1.0
# Y_Tuesday_Single-Leg Dumbbell Calf Raise = 1.0
# Y_Tuesday_Smith Machine Calf Raise = 1.0
# Y_Tuesday_Seated Calf Raise = 1.0
# Y_Tuesday_Seated Single-Leg Calf Raise = 1.0
# Y_Tuesday_Alternating Dumbbell Bench Press = 1.0
# Y_Tuesday_Barbell Bench Press = 1.0
# Y_Tuesday_Chest Press = 1.0
# Y_Tuesday_Decline Dumbbell Bench Press = 1.0
# Y_Tuesday_Decline Smith Machine Bench Press = 1.0
# Y_Tuesday_Dumbbell Bench Press = 1.0
# Y_Tuesday_Dumbbell Push-Up = 1.0
# Y_Tuesday_Elevated Push-Up = 1.0
# Y_Tuesday_Flat Bench Press = 1.0
# Y_Tuesday_Incline Alternating Dumbbell Bench Press = 1.0
# Y_Tuesday_Incline Barbell Bench Press = 1.0
# Y_Tuesday_Incline Bench Press = 1.0
# Y_Tuesday_Incline Dumbbell Bench Press = 1.0
# Y_Tuesday_Incline Hammer Dumbbell Bench Press = 1.0
# Y_Tuesday_Incline Single-Arm Dumbbell Bench Press = 1.0
# Y_Tuesday_Incline Smith Machine Bench Press = 1.0
# Y_Tuesday_Incline Twisting Dumbbell Bench Press = 1.0
# Y_Tuesday_Kneeling Push-Up = 1.0
# Y_Tuesday_Machine Bench Press = 1.0
# Y_Tuesday_Machine Vertical Bench Press = 1.0
# Y_Tuesday_Medicine Ball Crossover Push-Up = 1.0
# Y_Tuesday_Push-Up = 1.0
# Y_Tuesday_Single-Arm Dumbbell Bench Press = 1.0
# Y_Tuesday_Smith Machine Bench Press = 1.0
# Y_Tuesday_Twisting Dumbbell Bench Press = 1.0
# Y_Tuesday_Wide-Grip Push-Up = 1.0
# Y_Tuesday_Cable Crossover = 1.0
# Y_Tuesday_Cable Fly = 1.0
# Y_Tuesday_Decline Dumbbell Fly = 1.0
# Y_Tuesday_Dumbbell Fly = 1.0
# Y_Tuesday_High Cable Crossover = 1.0
# Y_Tuesday_Incline Cable Fly = 1.0
# Y_Tuesday_Incline Dumbbell Fly = 1.0
# Y_Tuesday_Incline Twisting Dumbbell Fly = 1.0
# Y_Tuesday_Low Cable Crossover = 1.0
# Y_Tuesday_Pec Deck = 1.0
# Y_Tuesday_Pec Deck Fly = 1.0
# Y_Tuesday_Bent-Knee Single-Leg Hip Lift = 1.0
# Y_Tuesday_Elevated Hip Lift = 1.0
# Y_Tuesday_Elevated Single-Leg Hip Lift = 1.0
# Y_Tuesday_Hip Lift = 1.0
# Y_Tuesday_Single-Leg Hip Lift = 1.0
# Y_Tuesday_Deadlift = 1.0
# Y_Tuesday_Leg Curl = 1.0
# Y_Tuesday_Lying Alternating Leg Curl = 1.0
# Y_Tuesday_Lying Leg Curl = 1.0
# Y_Tuesday_Lying Single-Leg Curl = 1.0
# Y_Tuesday_Seated Leg Curl = 1.0
# Y_Tuesday_Barbell Diagonal Lunge = 1.0
# Y_Tuesday_Barbell Hack Squat = 1.0
# Y_Tuesday_Barbell Lunge = 1.0
# Y_Tuesday_Barbell Reverse Lunge = 1.0
# Y_Tuesday_Barbell Side Lunge = 1.0
# Y_Tuesday_Barbell Split Squat = 1.0
# Y_Tuesday_Barbell Squat = 1.0
# Y_Tuesday_Barbell Step-Up = 1.0
# Y_Tuesday_Barbell Walking Lunge = 1.0
# Y_Tuesday_Diagonal Lunge = 1.0
# Y_Tuesday_Dumbbell Diagonal Lunge = 1.0
# Y_Tuesday_Dumbbell Lunge = 1.0
# Y_Tuesday_Dumbbell Reverse Lunge = 1.0
# Y_Tuesday_Dumbbell Side Lunge = 1.0
# Y_Tuesday_Dumbbell Split Squat = 1.0
# Y_Tuesday_Dumbbell Squat = 1.0
# Y_Tuesday_Dumbbell Step-Up = 1.0
# Y_Tuesday_Dumbbell Walking Lunge = 1.0
# Y_Tuesday_Forward Lunge = 1.0
# Y_Tuesday_Lateral Barbell Squat = 1.0
# Y_Tuesday_Lateral Barbell Step-Up = 1.0
# Y_Tuesday_Lateral Squat = 1.0
# Y_Tuesday_Lateral Step-Up = 1.0
# Y_Tuesday_Leg Press = 1.0
# Y_Tuesday_Lunge = 1.0
# Y_Tuesday_Lying Machine Squat = 1.0
# Y_Tuesday_Machine Hack Squat = 1.0
# Y_Tuesday_Reverse Lunge = 1.0
# Y_Tuesday_Single-Arm Barbell Side Squat = 1.0
# Y_Tuesday_Single-Arm Dumbbell Side Squat = 1.0
# Y_Tuesday_Single-Leg Barbell Squat = 1.0
# Y_Tuesday_Single-Leg Box Squat = 1.0
# Y_Tuesday_Single-Leg Dumbbell Box Squat = 1.0
# Y_Tuesday_Single-Leg Dumbbell Squat = 1.0
# Y_Tuesday_Single-Leg Squat = 1.0
# Y_Tuesday_Smith Machine Squat = 1.0
# Y_Tuesday_Split Squat = 1.0
# Y_Tuesday_Step-Up = 1.0
# Y_Tuesday_Walking Lunge = 1.0
# Y_Tuesday_Alternating Leg Extension = 1.0
# Y_Tuesday_Leg Extension = 1.0
# Y_Tuesday_Single-Leg Extension = 1.0
# Y_Tuesday_Alternating Superman = 1.0
# Y_Tuesday_Back Raise = 1.0
# Y_Tuesday_Quadruped Alternating Superman = 1.0
# Y_Tuesday_Superman = 1.0
# Y_Tuesday_Superman Hold = 1.0
# Y_Tuesday_Arnold Dumbbell Press = 1.0
# Y_Tuesday_Barbell Shoulder Press = 1.0
# Y_Tuesday_Dumbbell Alternating Shoulder Press = 1.0
# Y_Tuesday_Dumbbell Front Raise = 1.0
# Y_Tuesday_Dumbbell Shoulder Press = 1.0
# Y_Tuesday_Dumbbell Twisting Shoulder Press = 1.0
# Y_Tuesday_Machine Shoulder Press = 1.0
# Y_Tuesday_Seated Dumbbell Rear Delt Elbow Raise = 1.0
# Y_Tuesday_Single-Arm Dumbbell Shoulder Press = 1.0
# Y_Tuesday_Smith Machine Shoulder Press = 1.0
# Y_Tuesday_Barbell Front Raise = 1.0
# Y_Tuesday_Bent-Over Cable Rear Delt Raise = 1.0
# Y_Tuesday_Bent-Over Dumbbell Rear Delt Raise = 1.0
# Y_Tuesday_Cable Front Raise = 1.0
# Y_Tuesday_Cable Lateral Raise = 1.0
# Y_Tuesday_Dumbbell Lateral Raise = 1.0
# Y_Tuesday_Front Plate Raise = 1.0
# Y_Tuesday_Kneeling Single-Arm Cable Rear Delt Raise = 1.0
# Y_Tuesday_Lying Dumbbell External Rotation = 1.0
# Y_Tuesday_Lying Dumbbell Rear Delt Raise = 1.0
# Y_Tuesday_Lying Single-Arm Dumbbell Rear Delt Raise = 1.0
# Y_Tuesday_Pec Deck Real Delt Extensions = 1.0
# Y_Tuesday_Reverse Incline Dumbbell Rear Delt Raise = 1.0
# Y_Tuesday_Seated Dumbbell Rear Delt Raise = 1.0
# Y_Tuesday_Single-Arm Cable Lateral Raise = 1.0
# Y_Tuesday_Cable External Rotation = 1.0
# Y_Tuesday_Close-Grip Bench Press = 1.0
# Y_Tuesday_Forward Lean Dips = 1.0
# Y_Tuesday_Assisted Dips = 1.0
# Y_Tuesday_Bench Dips = 1.0
# Y_Tuesday_Diamond Push-Up = 1.0
# Y_Tuesday_Dips = 1.0
# Y_Tuesday_Machine Dips = 1.0
# Y_Tuesday_Decline Dumbbell Triceps Extension = 1.0
# Y_Tuesday_Decline EZ-Bar Tricep Extension = 1.0
# Y_Tuesday_Decline Single Dumbbell Triceps Extension = 1.0
# Y_Tuesday_Decline Single-Arm Dumbbell Triceps Extension = 1.0
# Y_Tuesday_Dumbbell Kickback = 1.0
# Y_Tuesday_Incline EZ-Bar Tricep Extension = 1.0
# Y_Tuesday_Kneeling Cable Triceps Extension = 1.0
# Y_Tuesday_Leaning Overhead Tricep Extension = 1.0
# Y_Tuesday_Low Cable Triceps Extension = 1.0
# Y_Tuesday_Lying Cable Triceps Extension = 1.0
# Y_Tuesday_Lying EZ-Bar Triceps Extension = 1.0
# Y_Tuesday_Lying Overhead EZ-Bar Tricep Extension = 1.0
# Y_Tuesday_Lying Reverse EZ-Bar Triceps Extension = 1.0
# Y_Tuesday_Lying Single Dumbbell Triceps Extension = 1.0
# Y_Tuesday_Lying Single-Arm Dumbbell Triceps Extension = 1.0
# Y_Tuesday_Lying Tricep Extensions = 1.0
# Y_Tuesday_Overhead Dumbbell Triceps Extension = 1.0
# Y_Tuesday_Overhead EZ-Bar Triceps Extension = 1.0
# Y_Tuesday_Overhead Rope Cable Tricep Extension = 1.0
# Y_Tuesday_Overhead Single Dumbbell Tricep Extension = 1.0
# Y_Tuesday_Overhead Single-Arm Cable Tricep Extension = 1.0
# Y_Tuesday_Overhead Single-Arm Dumbbell Tricep Extension = 1.0
# Y_Tuesday_Reverse Tricep Pushdown = 1.0
# Y_Tuesday_Rope Triceps Pushdown = 1.0
# Y_Tuesday_Single-Arm Towel Triceps Pushdown = 1.0
# Y_Tuesday_Single-Arm Triceps Pushdown = 1.0
# Y_Tuesday_Towel Triceps Pushdown = 1.0
# Y_Tuesday_Tricep Extensions = 1.0
# Y_Tuesday_Tricep Pushdown = 1.0
# Y_Tuesday_Tricep Pushdown = 1.0
# Y_Tuesday_V-Bar Tricep Pushdown = 1.0
# Y_Wednesday_Race walking = 1.0
# Y_Wednesday_Walking, under 2.0 mph, very slow = 1.0
# Y_Wednesday_Walking 2.0 mph, slow = 1.0
# Y_Wednesday_Walking 2.5 mph = 1.0
# Y_Wednesday_Walking 3.0 mph, moderate = 1.0
# Y_Wednesday_Walking 3.5 mph, brisk pace = 1.0
# Y_Wednesday_Walking 3.5 mph, uphill = 1.0
# Y_Wednesday_Walking 4.0 mph, very brisk = 1.0
# Y_Wednesday_Walking 4.5 mph = 1.0
# Y_Wednesday_Walking 5.0 mph = 1.0
# Y_Wednesday_Stretching, hatha yoga = 1.0
# Y_Wednesday_Mild stretching = 1.0
# Y_Wednesday_Stair machine = 1.0
# Y_Wednesday_Running, 5 mph (12 minute mile) = 1.0
# Y_Wednesday_Running, 5.2 mph (11.5 minute mile) = 1.0
# Y_Wednesday_Running, 6 mph (10 min mile) = 1.0
# Y_Wednesday_Running, 6.7 mph (9 min mile) = 1.0
# Y_Wednesday_Running, 7 mph (8.5 min mile) = 1.0
# Y_Wednesday_Running, 7.5mph (8 min mile) = 1.0
# Y_Wednesday_Running, 8 mph (7.5 min mile) = 1.0
# Y_Wednesday_Running, 8.6 mph (7 min mile) = 1.0
# Y_Wednesday_Running, general = 1.0
# Y_Wednesday_Jumping rope, fast = 1.0
# Y_Wednesday_Jumping rope, moderate = 1.0
# Y_Wednesday_Jumping rope, slow = 1.0
# Y_Wednesday_Cycling, mountain bike, bmx = 1.0
# Y_Wednesday_Cycling, <10 mph, leisure bicycling = 1.0
# Y_Wednesday_Cycling, 10-11.9 mph, light = 1.0
# Y_Wednesday_Cycling, 12-13.9 mph, moderate = 1.0
# Y_Wednesday_Cycling, 14-15.9 mph, vigorous = 1.0
# Y_Wednesday_Cycling, 16-19 mph, very fast, racing = 1.0
# Y_Wednesday_Stationary cycling, very light = 1.0
# Y_Wednesday_Stationary cycling, light = 1.0
# Y_Wednesday_Stationary cycling, moderate = 1.0
# Y_Wednesday_Stationary cycling, vigorous = 1.0
# Y_Wednesday_Stationary cycling, very vigorous = 1.0
# Y_Wednesday_Circuit training, minimal rest = 1.0
# Y_Wednesday_Aerobics, low impact = 1.0
# Y_Wednesday_Aerobics, high impact = 1.0
# Y_Wednesday_Aerobics, step aerobics = 1.0
# Y_Wednesday_Aerobics, general = 1.0
# Y_Wednesday_Rock climbing, mountain climbing = 1.0
# Y_Wednesday_Playing volleyball = 1.0
# Y_Wednesday_Volleyball, beach = 1.0
# Y_Wednesday_Playing tennis = 1.0
# Y_Wednesday_Tennis, doubles = 1.0
# Y_Wednesday_Tennis, singles = 1.0
# Y_Wednesday_Swimming, fast = 1.0
# Y_Wednesday_Swimming, slow = 1.0
# Y_Wednesday_Squash = 1.0
# Y_Wednesday_Softball or baseball = 1.0
# Y_Wednesday_Skiing, water skiing = 1.0
# Y_Wednesday_Ski mobiling = 1.0
# Y_Wednesday_Skin diving, moderate = 1.0
# Y_Wednesday_Skin diving, scuba diving = 1.0
# Y_Wednesday_Roller skating = 1.0
# Y_Wednesday_Roller blading, in-line skating = 1.0
# Y_Wednesday_Ice skating, average speed = 1.0
# Y_Wednesday_Ice skating, rapidly = 1.0
# Y_Wednesday_Skateboarding = 1.0
# Y_Wednesday_Soccer = 1.0
# Y_Wednesday_Juggling = 1.0
# Y_Wednesday_Rugby = 1.0
# Y_Wednesday_Playing paddleball = 1.0
# Y_Wednesday_Riding a horse, general = 1.0
# Y_Wednesday_Hockey, field hockey = 1.0
# Y_Wednesday_Hockey, ice hockey = 1.0
# Y_Wednesday_Handball = 1.0
# Y_Wednesday_Handball, team = 1.0
# Y_Wednesday_Frisbee playing, general = 1.0
# Y_Wednesday_Frisbee, ultimate frisbee = 1.0
# Y_Wednesday_Football, touch, flag, general = 1.0
# Y_Wednesday_Football or baseball, playing catch = 1.0
# Y_Wednesday_Ballet, twist, jazz, tap = 1.0
# Y_Wednesday_Ballroom dancing, slow = 1.0
# Y_Wednesday_Ballroom dancing, fast = 1.0
# Y_Wednesday_Rock climbing, ascending rock = 1.0
# Y_Wednesday_Rock climbing, rappelling = 1.0
# Y_Wednesday_Boxing, punching bag = 1.0
# Y_Wednesday_Boxing, sparring = 1.0
# Y_Wednesday_Bowling = 1.0
# Y_Wednesday_Playing basketball, non game = 1.0
# Y_Wednesday_Basketball, shooting baskets = 1.0
# Y_Wednesday_Badminton = 1.0
# Y_Wednesday_Archery = 1.0
# Y_Wednesday_Water aerobics = 1.0
# Y_Wednesday_Full Reverse Crunch - Lower = 1.0
# Y_Wednesday_Full Reverse Crunch - Obliques = 1.0
# Y_Wednesday_Full Reverse Crunch - Total = 1.0
# Y_Wednesday_Full Reverse Crunch - Upper = 1.0
# Y_Wednesday_Full Reverse Crunch = 1.0
# Y_Wednesday_Close-Grip Lat Pulldown = 1.0
# Y_Wednesday_Inverted Pull-Up = 1.0
# Y_Wednesday_Lat Pulldown = 1.0
# Y_Wednesday_Pull-Up = 1.0
# Y_Wednesday_Reverse-Grip Lat Pullown = 1.0
# Y_Wednesday_Reverse-Grip Pull-Up = 1.0
# Y_Wednesday_V-Bar Pull-Up = 1.0
# Y_Wednesday_Wide-Grip Lat Pulldown = 1.0
# Y_Wednesday_Bent-Over Alternating Dumbbell Row = 1.0
# Y_Wednesday_Bent-Over Barbell Row = 1.0
# Y_Wednesday_Bent-Over Dumbbell Row = 1.0
# Y_Wednesday_Bent-Over Hammer Dumbbell Row = 1.0
# Y_Wednesday_Bent-Over Long Barbell Row = 1.0
# Y_Wednesday_Bent-Over Reverse-Grip Barbell Row = 1.0
# Y_Wednesday_Bent-Over Single-Arm Long Barbell Row = 1.0
# Y_Wednesday_Machine Row = 1.0
# Y_Wednesday_One Arm Dumbbell Row = 1.0
# Y_Wednesday_Reverse Incline Dumbbell Row = 1.0
# Y_Wednesday_Rope Cable Row = 1.0
# Y_Wednesday_Seated Cable Row = 1.0
# Y_Wednesday_Seated Row = 1.0
# Y_Wednesday_Single-Arm Cable Row = 1.0
# Y_Wednesday_Single-Arm Dumbbell Row = 1.0
# Y_Wednesday_Single-Arm Lat Pulldown = 1.0
# Y_Wednesday_Standing Cable Row = 1.0
# Y_Wednesday_Standing Single-Arm Cable Row = 1.0
# Y_Wednesday_Alternating Dumbbell Curl = 1.0
# Y_Wednesday_Alternating Hammer Curl = 1.0
# Y_Wednesday_Barbell Curl = 1.0
# Y_Wednesday_Bicep Curl = 1.0
# Y_Wednesday_Bottom/Top/Full Curls = 1.0
# Y_Wednesday_Cable Curl = 1.0
# Y_Wednesday_Concentration Dumbbell Curl = 1.0
# Y_Wednesday_Cross Body Hammer Curl = 1.0
# Y_Wednesday_Dumbbell Curl = 1.0
# Y_Wednesday_EZ-Bar Curl = 1.0
# Y_Wednesday_Hammer Curl = 1.0
# Y_Wednesday_Incline Alternating Dumbbell Curl = 1.0
# Y_Wednesday_Incline Alternating Hammer Curl = 1.0
# Y_Wednesday_Incline Dumbbell Curl = 1.0
# Y_Wednesday_Incline Hammer Curl = 1.0
# Y_Wednesday_Kneeling Cable Curl = 1.0
# Y_Wednesday_Lying Cable Curl = 1.0
# Y_Wednesday_Lying Double Biceps Cable Curl = 1.0
# Y_Wednesday_Lying High Cable Curl = 1.0
# Y_Wednesday_Machine Curl = 1.0
# Y_Wednesday_Overhead Double Biceps Cable Curl = 1.0
# Y_Wednesday_Overhead Rope Cable Curl = 1.0
# Y_Wednesday_Preacher Barbell Curl = 1.0
# Y_Wednesday_Preacher Cable Curl = 1.0
# Y_Wednesday_Preacher Dumbbell Curl = 1.0
# Y_Wednesday_Preacher EZ-Bar Curl = 1.0
# Y_Wednesday_Preacher Hammer Dumbbell Curl = 1.0
# Y_Wednesday_Preacher Single-Arm Dumbbell Curl = 1.0
# Y_Wednesday_Reverse Curl = 1.0
# Y_Wednesday_Rope Cable Curl = 1.0
# Y_Wednesday_Seated Alternating Curl = 1.0
# Y_Wednesday_Seated Alternating Hammer Curl = 1.0
# Y_Wednesday_Seated Dumbbell Curl = 1.0
# Y_Wednesday_Seated Hammer Curl = 1.0
# Y_Wednesday_Single-Arm Barbell Curl = 1.0
# Y_Wednesday_Single-Arm Cable Curl = 1.0
# Y_Wednesday_Single-Arm Dumbbell Curl w/ Incline Bench = 1.0
# Y_Wednesday_Spider Curl = 1.0
# Y_Wednesday_Barbell Calf Raise = 1.0
# Y_Wednesday_Calf Press = 1.0
# Y_Wednesday_Calf Raise - Seated = 1.0
# Y_Wednesday_Calf Raise - Standing = 1.0
# Y_Wednesday_Dumbbell Calf Raise = 1.0
# Y_Wednesday_Single-Leg Calf Press = 1.0
# Y_Wednesday_Single-Leg Dumbbell Calf Raise = 1.0
# Y_Wednesday_Smith Machine Calf Raise = 1.0
# Y_Wednesday_Seated Calf Raise = 1.0
# Y_Wednesday_Seated Single-Leg Calf Raise = 1.0
# Y_Wednesday_Alternating Dumbbell Bench Press = 1.0
# Y_Wednesday_Barbell Bench Press = 1.0
# Y_Wednesday_Chest Press = 1.0
# Y_Wednesday_Decline Dumbbell Bench Press = 1.0
# Y_Wednesday_Decline Smith Machine Bench Press = 1.0
# Y_Wednesday_Dumbbell Bench Press = 1.0
# Y_Wednesday_Dumbbell Push-Up = 1.0
# Y_Wednesday_Elevated Push-Up = 1.0
# Y_Wednesday_Flat Bench Press = 1.0
# Y_Wednesday_Incline Alternating Dumbbell Bench Press = 1.0
# Y_Wednesday_Incline Barbell Bench Press = 1.0
# Y_Wednesday_Incline Bench Press = 1.0
# Y_Wednesday_Incline Dumbbell Bench Press = 1.0
# Y_Wednesday_Incline Hammer Dumbbell Bench Press = 1.0
# Y_Wednesday_Incline Single-Arm Dumbbell Bench Press = 1.0
# Y_Wednesday_Incline Smith Machine Bench Press = 1.0
# Y_Wednesday_Incline Twisting Dumbbell Bench Press = 1.0
# Y_Wednesday_Kneeling Push-Up = 1.0
# Y_Wednesday_Machine Bench Press = 1.0
# Y_Wednesday_Machine Vertical Bench Press = 1.0
# Y_Wednesday_Medicine Ball Crossover Push-Up = 1.0
# Y_Wednesday_Push-Up = 1.0
# Y_Wednesday_Single-Arm Dumbbell Bench Press = 1.0
# Y_Wednesday_Smith Machine Bench Press = 1.0
# Y_Wednesday_Twisting Dumbbell Bench Press = 1.0
# Y_Wednesday_Wide-Grip Push-Up = 1.0
# Y_Wednesday_Cable Crossover = 1.0
# Y_Wednesday_Cable Fly = 1.0
# Y_Wednesday_Decline Dumbbell Fly = 1.0
# Y_Wednesday_Dumbbell Fly = 1.0
# Y_Wednesday_High Cable Crossover = 1.0
# Y_Wednesday_Incline Cable Fly = 1.0
# Y_Wednesday_Incline Dumbbell Fly = 1.0
# Y_Wednesday_Incline Twisting Dumbbell Fly = 1.0
# Y_Wednesday_Low Cable Crossover = 1.0
# Y_Wednesday_Pec Deck = 1.0
# Y_Wednesday_Pec Deck Fly = 1.0
# Y_Wednesday_Bent-Knee Single-Leg Hip Lift = 1.0
# Y_Wednesday_Elevated Hip Lift = 1.0
# Y_Wednesday_Elevated Single-Leg Hip Lift = 1.0
# Y_Wednesday_Hip Lift = 1.0
# Y_Wednesday_Single-Leg Hip Lift = 1.0
# Y_Wednesday_Deadlift = 1.0
# Y_Wednesday_Leg Curl = 1.0
# Y_Wednesday_Lying Alternating Leg Curl = 1.0
# Y_Wednesday_Lying Leg Curl = 1.0
# Y_Wednesday_Lying Single-Leg Curl = 1.0
# Y_Wednesday_Seated Leg Curl = 1.0
# Y_Wednesday_Barbell Diagonal Lunge = 1.0
# Y_Wednesday_Barbell Hack Squat = 1.0
# Y_Wednesday_Barbell Lunge = 1.0
# Y_Wednesday_Barbell Reverse Lunge = 1.0
# Y_Wednesday_Barbell Side Lunge = 1.0
# Y_Wednesday_Barbell Split Squat = 1.0
# Y_Wednesday_Barbell Squat = 1.0
# Y_Wednesday_Barbell Step-Up = 1.0
# Y_Wednesday_Barbell Walking Lunge = 1.0
# Y_Wednesday_Diagonal Lunge = 1.0
# Y_Wednesday_Dumbbell Diagonal Lunge = 1.0
# Y_Wednesday_Dumbbell Lunge = 1.0
# Y_Wednesday_Dumbbell Reverse Lunge = 1.0
# Y_Wednesday_Dumbbell Side Lunge = 1.0
# Y_Wednesday_Dumbbell Split Squat = 1.0
# Y_Wednesday_Dumbbell Squat = 1.0
# Y_Wednesday_Dumbbell Step-Up = 1.0
# Y_Wednesday_Dumbbell Walking Lunge = 1.0
# Y_Wednesday_Forward Lunge = 1.0
# Y_Wednesday_Lateral Barbell Squat = 1.0
# Y_Wednesday_Lateral Barbell Step-Up = 1.0
# Y_Wednesday_Lateral Squat = 1.0
# Y_Wednesday_Lateral Step-Up = 1.0
# Y_Wednesday_Leg Press = 1.0
# Y_Wednesday_Lunge = 1.0
# Y_Wednesday_Lying Machine Squat = 1.0
# Y_Wednesday_Machine Hack Squat = 1.0
# Y_Wednesday_Reverse Lunge = 1.0
# Y_Wednesday_Single-Arm Barbell Side Squat = 1.0
# Y_Wednesday_Single-Arm Dumbbell Side Squat = 1.0
# Y_Wednesday_Single-Leg Barbell Squat = 1.0
# Y_Wednesday_Single-Leg Box Squat = 1.0
# Y_Wednesday_Single-Leg Dumbbell Box Squat = 1.0
# Y_Wednesday_Single-Leg Dumbbell Squat = 1.0
# Y_Wednesday_Single-Leg Squat = 1.0
# Y_Wednesday_Smith Machine Squat = 1.0
# Y_Wednesday_Split Squat = 1.0
# Y_Wednesday_Step-Up = 1.0
# Y_Wednesday_Walking Lunge = 1.0
# Y_Wednesday_Alternating Leg Extension = 1.0
# Y_Wednesday_Leg Extension = 1.0
# Y_Wednesday_Single-Leg Extension = 1.0
# Y_Wednesday_Alternating Superman = 1.0
# Y_Wednesday_Back Raise = 1.0
# Y_Wednesday_Quadruped Alternating Superman = 1.0
# Y_Wednesday_Superman = 1.0
# Y_Wednesday_Superman Hold = 1.0
# Y_Wednesday_Arnold Dumbbell Press = 1.0
# Y_Wednesday_Barbell Shoulder Press = 1.0
# Y_Wednesday_Dumbbell Alternating Shoulder Press = 1.0
# Y_Wednesday_Dumbbell Front Raise = 1.0
# Y_Wednesday_Dumbbell Shoulder Press = 1.0
# Y_Wednesday_Dumbbell Twisting Shoulder Press = 1.0
# Y_Wednesday_Machine Shoulder Press = 1.0
# Y_Wednesday_Seated Dumbbell Rear Delt Elbow Raise = 1.0
# Y_Wednesday_Single-Arm Dumbbell Shoulder Press = 1.0
# Y_Wednesday_Smith Machine Shoulder Press = 1.0
# Y_Wednesday_Barbell Front Raise = 1.0
# Y_Wednesday_Bent-Over Cable Rear Delt Raise = 1.0
# Y_Wednesday_Bent-Over Dumbbell Rear Delt Raise = 1.0
# Y_Wednesday_Cable Front Raise = 1.0
# Y_Wednesday_Cable Lateral Raise = 1.0
# Y_Wednesday_Dumbbell Lateral Raise = 1.0
# Y_Wednesday_Front Plate Raise = 1.0
# Y_Wednesday_Kneeling Single-Arm Cable Rear Delt Raise = 1.0
# Y_Wednesday_Lying Dumbbell External Rotation = 1.0
# Y_Wednesday_Lying Dumbbell Rear Delt Raise = 1.0
# Y_Wednesday_Lying Single-Arm Dumbbell Rear Delt Raise = 1.0
# Y_Wednesday_Pec Deck Real Delt Extensions = 1.0
# Y_Wednesday_Reverse Incline Dumbbell Rear Delt Raise = 1.0
# Y_Wednesday_Seated Dumbbell Rear Delt Raise = 1.0
# Y_Wednesday_Single-Arm Cable Lateral Raise = 1.0
# Y_Wednesday_Cable External Rotation = 1.0
# Y_Wednesday_Close-Grip Bench Press = 1.0
# Y_Wednesday_Forward Lean Dips = 1.0
# Y_Wednesday_Assisted Dips = 1.0
# Y_Wednesday_Bench Dips = 1.0
# Y_Wednesday_Diamond Push-Up = 1.0
# Y_Wednesday_Dips = 1.0
# Y_Wednesday_Machine Dips = 1.0
# Y_Wednesday_Decline Dumbbell Triceps Extension = 1.0
# Y_Wednesday_Decline EZ-Bar Tricep Extension = 1.0
# Y_Wednesday_Decline Single Dumbbell Triceps Extension = 1.0
# Y_Wednesday_Decline Single-Arm Dumbbell Triceps Extension = 1.0
# Y_Wednesday_Dumbbell Kickback = 1.0
# Y_Wednesday_Incline EZ-Bar Tricep Extension = 1.0
# Y_Wednesday_Kneeling Cable Triceps Extension = 1.0
# Y_Wednesday_Leaning Overhead Tricep Extension = 1.0
# Y_Wednesday_Low Cable Triceps Extension = 1.0
# Y_Wednesday_Lying Cable Triceps Extension = 1.0
# Y_Wednesday_Lying EZ-Bar Triceps Extension = 1.0
# Y_Wednesday_Lying Overhead EZ-Bar Tricep Extension = 1.0
# Y_Wednesday_Lying Reverse EZ-Bar Triceps Extension = 1.0
# Y_Wednesday_Lying Single Dumbbell Triceps Extension = 1.0
# Y_Wednesday_Lying Single-Arm Dumbbell Triceps Extension = 1.0
# Y_Wednesday_Lying Tricep Extensions = 1.0
# Y_Wednesday_Overhead Dumbbell Triceps Extension = 1.0
# Y_Wednesday_Overhead EZ-Bar Triceps Extension = 1.0
# Y_Wednesday_Overhead Rope Cable Tricep Extension = 1.0
# Y_Wednesday_Overhead Single Dumbbell Tricep Extension = 1.0
# Y_Wednesday_Overhead Single-Arm Cable Tricep Extension = 1.0
# Y_Wednesday_Overhead Single-Arm Dumbbell Tricep Extension = 1.0
# Y_Wednesday_Reverse Tricep Pushdown = 1.0
# Y_Wednesday_Rope Triceps Pushdown = 1.0
# Y_Wednesday_Single-Arm Towel Triceps Pushdown = 1.0
# Y_Wednesday_Single-Arm Triceps Pushdown = 1.0
# Y_Wednesday_Towel Triceps Pushdown = 1.0
# Y_Wednesday_Tricep Extensions = 1.0
# Y_Wednesday_Tricep Pushdown = 1.0
# Y_Wednesday_Tricep Pushdown = 1.0
# Y_Wednesday_V-Bar Tricep Pushdown = 1.0
# Y_Thursday_Race walking = 1.0
# Y_Thursday_Walking, under 2.0 mph, very slow = 1.0
# Y_Thursday_Walking 2.0 mph, slow = 1.0
# Y_Thursday_Walking 2.5 mph = 1.0
# Y_Thursday_Walking 3.0 mph, moderate = 1.0
# Y_Thursday_Walking 3.5 mph, brisk pace = 1.0
# Y_Thursday_Walking 3.5 mph, uphill = 1.0
# Y_Thursday_Walking 4.0 mph, very brisk = 1.0
# Y_Thursday_Walking 4.5 mph = 1.0
# Y_Thursday_Walking 5.0 mph = 1.0
# Y_Thursday_Stretching, hatha yoga = 1.0
# Y_Thursday_Mild stretching = 1.0
# Y_Thursday_Stair machine = 1.0
# Y_Thursday_Running, 5 mph (12 minute mile) = 1.0
# Y_Thursday_Running, 5.2 mph (11.5 minute mile) = 1.0
# Y_Thursday_Running, 6 mph (10 min mile) = 1.0
# Y_Thursday_Running, 6.7 mph (9 min mile) = 1.0
# Y_Thursday_Running, 7 mph (8.5 min mile) = 1.0
# Y_Thursday_Running, 7.5mph (8 min mile) = 1.0
# Y_Thursday_Running, 8 mph (7.5 min mile) = 1.0
# Y_Thursday_Running, 8.6 mph (7 min mile) = 1.0
# Y_Thursday_Running, general = 1.0
# Y_Thursday_Jumping rope, fast = 1.0
# Y_Thursday_Jumping rope, moderate = 1.0
# Y_Thursday_Jumping rope, slow = 1.0
# Y_Thursday_Cycling, mountain bike, bmx = 1.0
# Y_Thursday_Cycling, <10 mph, leisure bicycling = 1.0
# Y_Thursday_Cycling, 10-11.9 mph, light = 1.0
# Y_Thursday_Cycling, 12-13.9 mph, moderate = 1.0
# Y_Thursday_Cycling, 14-15.9 mph, vigorous = 1.0
# Y_Thursday_Cycling, 16-19 mph, very fast, racing = 1.0
# Y_Thursday_Stationary cycling, very light = 1.0
# Y_Thursday_Stationary cycling, light = 1.0
# Y_Thursday_Stationary cycling, moderate = 1.0
# Y_Thursday_Stationary cycling, vigorous = 1.0
# Y_Thursday_Stationary cycling, very vigorous = 1.0
# Y_Thursday_Circuit training, minimal rest = 1.0
# Y_Thursday_Aerobics, low impact = 1.0
# Y_Thursday_Aerobics, high impact = 1.0
# Y_Thursday_Aerobics, step aerobics = 1.0
# Y_Thursday_Aerobics, general = 1.0
# Y_Thursday_Rock climbing, mountain climbing = 1.0
# Y_Thursday_Playing volleyball = 1.0
# Y_Thursday_Volleyball, beach = 1.0
# Y_Thursday_Playing tennis = 1.0
# Y_Thursday_Tennis, doubles = 1.0
# Y_Thursday_Tennis, singles = 1.0
# Y_Thursday_Swimming, fast = 1.0
# Y_Thursday_Swimming, slow = 1.0
# Y_Thursday_Squash = 1.0
# Y_Thursday_Softball or baseball = 1.0
# Y_Thursday_Skiing, water skiing = 1.0
# Y_Thursday_Ski mobiling = 1.0
# Y_Thursday_Skin diving, moderate = 1.0
# Y_Thursday_Skin diving, scuba diving = 1.0
# Y_Thursday_Roller skating = 1.0
# Y_Thursday_Roller blading, in-line skating = 1.0
# Y_Thursday_Ice skating, average speed = 1.0
# Y_Thursday_Ice skating, rapidly = 1.0
# Y_Thursday_Skateboarding = 1.0
# Y_Thursday_Soccer = 1.0
# Y_Thursday_Juggling = 1.0
# Y_Thursday_Rugby = 1.0
# Y_Thursday_Playing paddleball = 1.0
# Y_Thursday_Riding a horse, general = 1.0
# Y_Thursday_Hockey, field hockey = 1.0
# Y_Thursday_Hockey, ice hockey = 1.0
# Y_Thursday_Handball = 1.0
# Y_Thursday_Handball, team = 1.0
# Y_Thursday_Frisbee playing, general = 1.0
# Y_Thursday_Frisbee, ultimate frisbee = 1.0
# Y_Thursday_Football, touch, flag, general = 1.0
# Y_Thursday_Football or baseball, playing catch = 1.0
# Y_Thursday_Ballet, twist, jazz, tap = 1.0
# Y_Thursday_Ballroom dancing, slow = 1.0
# Y_Thursday_Ballroom dancing, fast = 1.0
# Y_Thursday_Rock climbing, ascending rock = 1.0
# Y_Thursday_Rock climbing, rappelling = 1.0
# Y_Thursday_Boxing, punching bag = 1.0
# Y_Thursday_Boxing, sparring = 1.0
# Y_Thursday_Bowling = 1.0
# Y_Thursday_Playing basketball, non game = 1.0
# Y_Thursday_Basketball, shooting baskets = 1.0
# Y_Thursday_Badminton = 1.0
# Y_Thursday_Archery = 1.0
# Y_Thursday_Water aerobics = 1.0
# Y_Thursday_Full Reverse Crunch - Lower = 1.0
# Y_Thursday_Full Reverse Crunch - Obliques = 1.0
# Y_Thursday_Full Reverse Crunch - Total = 1.0
# Y_Thursday_Full Reverse Crunch - Upper = 1.0
# Y_Thursday_Full Reverse Crunch = 1.0
# Y_Thursday_Close-Grip Lat Pulldown = 1.0
# Y_Thursday_Inverted Pull-Up = 1.0
# Y_Thursday_Lat Pulldown = 1.0
# Y_Thursday_Pull-Up = 1.0
# Y_Thursday_Reverse-Grip Lat Pullown = 1.0
# Y_Thursday_Reverse-Grip Pull-Up = 1.0
# Y_Thursday_V-Bar Pull-Up = 1.0
# Y_Thursday_Wide-Grip Lat Pulldown = 1.0
# Y_Thursday_Bent-Over Alternating Dumbbell Row = 1.0
# Y_Thursday_Bent-Over Barbell Row = 1.0
# Y_Thursday_Bent-Over Dumbbell Row = 1.0
# Y_Thursday_Bent-Over Hammer Dumbbell Row = 1.0
# Y_Thursday_Bent-Over Long Barbell Row = 1.0
# Y_Thursday_Bent-Over Reverse-Grip Barbell Row = 1.0
# Y_Thursday_Bent-Over Single-Arm Long Barbell Row = 1.0
# Y_Thursday_Machine Row = 1.0
# Y_Thursday_One Arm Dumbbell Row = 1.0
# Y_Thursday_Reverse Incline Dumbbell Row = 1.0
# Y_Thursday_Rope Cable Row = 1.0
# Y_Thursday_Seated Cable Row = 1.0
# Y_Thursday_Seated Row = 1.0
# Y_Thursday_Single-Arm Cable Row = 1.0
# Y_Thursday_Single-Arm Dumbbell Row = 1.0
# Y_Thursday_Single-Arm Lat Pulldown = 1.0
# Y_Thursday_Standing Cable Row = 1.0
# Y_Thursday_Standing Single-Arm Cable Row = 1.0
# Y_Thursday_Alternating Dumbbell Curl = 1.0
# Y_Thursday_Alternating Hammer Curl = 1.0
# Y_Thursday_Barbell Curl = 1.0
# Y_Thursday_Bicep Curl = 1.0
# Y_Thursday_Bottom/Top/Full Curls = 1.0
# Y_Thursday_Cable Curl = 1.0
# Y_Thursday_Concentration Dumbbell Curl = 1.0
# Y_Thursday_Cross Body Hammer Curl = 1.0
# Y_Thursday_Dumbbell Curl = 1.0
# Y_Thursday_EZ-Bar Curl = 1.0
# Y_Thursday_Hammer Curl = 1.0
# Y_Thursday_Incline Alternating Dumbbell Curl = 1.0
# Y_Thursday_Incline Alternating Hammer Curl = 1.0
# Y_Thursday_Incline Dumbbell Curl = 1.0
# Y_Thursday_Incline Hammer Curl = 1.0
# Y_Thursday_Kneeling Cable Curl = 1.0
# Y_Thursday_Lying Cable Curl = 1.0
# Y_Thursday_Lying Double Biceps Cable Curl = 1.0
# Y_Thursday_Lying High Cable Curl = 1.0
# Y_Thursday_Machine Curl = 1.0
# Y_Thursday_Overhead Double Biceps Cable Curl = 1.0
# Y_Thursday_Overhead Rope Cable Curl = 1.0
# Y_Thursday_Preacher Barbell Curl = 1.0
# Y_Thursday_Preacher Cable Curl = 1.0
# Y_Thursday_Preacher Dumbbell Curl = 1.0
# Y_Thursday_Preacher EZ-Bar Curl = 1.0
# Y_Thursday_Preacher Hammer Dumbbell Curl = 1.0
# Y_Thursday_Preacher Single-Arm Dumbbell Curl = 1.0
# Y_Thursday_Reverse Curl = 1.0
# Y_Thursday_Rope Cable Curl = 1.0
# Y_Thursday_Seated Alternating Curl = 1.0
# Y_Thursday_Seated Alternating Hammer Curl = 1.0
# Y_Thursday_Seated Dumbbell Curl = 1.0
# Y_Thursday_Seated Hammer Curl = 1.0
# Y_Thursday_Single-Arm Barbell Curl = 1.0
# Y_Thursday_Single-Arm Cable Curl = 1.0
# Y_Thursday_Single-Arm Dumbbell Curl w/ Incline Bench = 1.0
# Y_Thursday_Spider Curl = 1.0
# Y_Thursday_Barbell Calf Raise = 1.0
# Y_Thursday_Calf Press = 1.0
# Y_Thursday_Calf Raise - Seated = 1.0
# Y_Thursday_Calf Raise - Standing = 1.0
# Y_Thursday_Dumbbell Calf Raise = 1.0
# Y_Thursday_Single-Leg Calf Press = 1.0
# Y_Thursday_Single-Leg Dumbbell Calf Raise = 1.0
# Y_Thursday_Smith Machine Calf Raise = 1.0
# Y_Thursday_Seated Calf Raise = 1.0
# Y_Thursday_Seated Single-Leg Calf Raise = 1.0
# Y_Thursday_Alternating Dumbbell Bench Press = 1.0
# Y_Thursday_Barbell Bench Press = 1.0
# Y_Thursday_Chest Press = 1.0
# Y_Thursday_Decline Dumbbell Bench Press = 1.0
# Y_Thursday_Decline Smith Machine Bench Press = 1.0
# Y_Thursday_Dumbbell Bench Press = 1.0
# Y_Thursday_Dumbbell Push-Up = 1.0
# Y_Thursday_Elevated Push-Up = 1.0
# Y_Thursday_Flat Bench Press = 1.0
# Y_Thursday_Incline Alternating Dumbbell Bench Press = 1.0
# Y_Thursday_Incline Barbell Bench Press = 1.0
# Y_Thursday_Incline Bench Press = 1.0
# Y_Thursday_Incline Dumbbell Bench Press = 1.0
# Y_Thursday_Incline Hammer Dumbbell Bench Press = 1.0
# Y_Thursday_Incline Single-Arm Dumbbell Bench Press = 1.0
# Y_Thursday_Incline Smith Machine Bench Press = 1.0
# Y_Thursday_Incline Twisting Dumbbell Bench Press = 1.0
# Y_Thursday_Kneeling Push-Up = 1.0
# Y_Thursday_Machine Bench Press = 1.0
# Y_Thursday_Machine Vertical Bench Press = 1.0
# Y_Thursday_Medicine Ball Crossover Push-Up = 1.0
# Y_Thursday_Push-Up = 1.0
# Y_Thursday_Single-Arm Dumbbell Bench Press = 1.0
# Y_Thursday_Smith Machine Bench Press = 1.0
# Y_Thursday_Twisting Dumbbell Bench Press = 1.0
# Y_Thursday_Wide-Grip Push-Up = 1.0
# Y_Thursday_Cable Crossover = 1.0
# Y_Thursday_Cable Fly = 1.0
# Y_Thursday_Decline Dumbbell Fly = 1.0
# Y_Thursday_Dumbbell Fly = 1.0
# Y_Thursday_High Cable Crossover = 1.0
# Y_Thursday_Incline Cable Fly = 1.0
# Y_Thursday_Incline Dumbbell Fly = 1.0
# Y_Thursday_Incline Twisting Dumbbell Fly = 1.0
# Y_Thursday_Low Cable Crossover = 1.0
# Y_Thursday_Pec Deck = 1.0
# Y_Thursday_Pec Deck Fly = 1.0
# Y_Thursday_Bent-Knee Single-Leg Hip Lift = 1.0
# Y_Thursday_Elevated Hip Lift = 1.0
# Y_Thursday_Elevated Single-Leg Hip Lift = 1.0
# Y_Thursday_Hip Lift = 1.0
# Y_Thursday_Single-Leg Hip Lift = 1.0
# Y_Thursday_Deadlift = 1.0
# Y_Thursday_Leg Curl = 1.0
# Y_Thursday_Lying Alternating Leg Curl = 1.0
# ...
# Y_Sunday_Full Reverse Crunch - Lower = 1.0
# Y_Sunday_Full Reverse Crunch - Obliques = 1.0
# Y_Sunday_Full Reverse Crunch - Total = 1.0
# Y_Sunday_Full Reverse Crunch - Upper = 1.0
# Y_Sunday_Full Reverse Crunch = 1.0
# Y_Sunday_Close-Grip Lat Pulldown = 1.0
# Y_Sunday_Inverted Pull-Up = 1.0
# Y_Sunday_Lat Pulldown = 1.0
# Y_Sunday_Pull-Up = 1.0
# Y_Sunday_Reverse-Grip Lat Pullown = 1.0
# Y_Sunday_Reverse-Grip Pull-Up = 1.0
# Y_Sunday_V-Bar Pull-Up = 1.0
# Y_Sunday_Wide-Grip Lat Pulldown = 1.0
# Y_Sunday_Bent-Over Alternating Dumbbell Row = 1.0
# Y_Sunday_Bent-Over Barbell Row = 1.0
# Y_Sunday_Bent-Over Dumbbell Row = 1.0
# Y_Sunday_Bent-Over Hammer Dumbbell Row = 1.0
# Y_Sunday_Bent-Over Long Barbell Row = 1.0
# Y_Sunday_Bent-Over Reverse-Grip Barbell Row = 1.0
# Y_Sunday_Bent-Over Single-Arm Long Barbell Row = 1.0
# Y_Sunday_Machine Row = 1.0
# Y_Sunday_One Arm Dumbbell Row = 1.0
# Y_Sunday_Reverse Incline Dumbbell Row = 1.0
# Y_Sunday_Rope Cable Row = 1.0
# Y_Sunday_Seated Cable Row = 1.0
# Y_Sunday_Seated Row = 1.0
# Y_Sunday_Single-Arm Cable Row = 1.0
# Y_Sunday_Single-Arm Dumbbell Row = 1.0
# Y_Sunday_Single-Arm Lat Pulldown = 1.0
# Y_Sunday_Standing Cable Row = 1.0
# Y_Sunday_Standing Single-Arm Cable Row = 1.0
# Y_Sunday_Alternating Dumbbell Curl = 1.0
# Y_Sunday_Alternating Hammer Curl = 1.0
# Y_Sunday_Barbell Curl = 1.0
# Y_Sunday_Bicep Curl = 1.0
# Y_Sunday_Bottom/Top/Full Curls = 1.0
# Y_Sunday_Cable Curl = 1.0
# Y_Sunday_Concentration Dumbbell Curl = 1.0
# Y_Sunday_Cross Body Hammer Curl = 1.0
# Y_Sunday_Dumbbell Curl = 1.0
# Y_Sunday_EZ-Bar Curl = 1.0
# Y_Sunday_Hammer Curl = 1.0
# Y_Sunday_Incline Alternating Dumbbell Curl = 1.0
# Y_Sunday_Incline Alternating Hammer Curl = 1.0
# Y_Sunday_Incline Dumbbell Curl = 1.0
# Y_Sunday_Incline Hammer Curl = 1.0
# Y_Sunday_Kneeling Cable Curl = 1.0
# Y_Sunday_Lying Cable Curl = 1.0
# Y_Sunday_Lying Double Biceps Cable Curl = 1.0
# Y_Sunday_Lying High Cable Curl = 1.0
# Y_Sunday_Machine Curl = 1.0
# Y_Sunday_Overhead Double Biceps Cable Curl = 1.0
# Y_Sunday_Overhead Rope Cable Curl = 1.0
# Y_Sunday_Preacher Barbell Curl = 1.0
# Y_Sunday_Preacher Cable Curl = 1.0
# Y_Sunday_Preacher Dumbbell Curl = 1.0
# Y_Sunday_Preacher EZ-Bar Curl = 1.0
# Y_Sunday_Preacher Hammer Dumbbell Curl = 1.0
# Y_Sunday_Preacher Single-Arm Dumbbell Curl = 1.0
# Y_Sunday_Reverse Curl = 1.0
# Y_Sunday_Rope Cable Curl = 1.0
# Y_Sunday_Seated Alternating Curl = 1.0
# Y_Sunday_Seated Alternating Hammer Curl = 1.0
# Y_Sunday_Seated Dumbbell Curl = 1.0
# Y_Sunday_Seated Hammer Curl = 1.0
# Y_Sunday_Single-Arm Barbell Curl = 1.0
# Y_Sunday_Single-Arm Cable Curl = 1.0
# Y_Sunday_Single-Arm Dumbbell Curl w/ Incline Bench = 1.0
# Y_Sunday_Spider Curl = 1.0
# Y_Sunday_Barbell Calf Raise = 1.0
# Y_Sunday_Calf Press = 1.0
# Y_Sunday_Calf Raise - Seated = 1.0
# Y_Sunday_Calf Raise - Standing = 1.0
# Y_Sunday_Dumbbell Calf Raise = 1.0
# Y_Sunday_Single-Leg Calf Press = 1.0
# Y_Sunday_Single-Leg Dumbbell Calf Raise = 1.0
# Y_Sunday_Smith Machine Calf Raise = 1.0
# Y_Sunday_Seated Calf Raise = 1.0
# Y_Sunday_Seated Single-Leg Calf Raise = 1.0
# Y_Sunday_Alternating Dumbbell Bench Press = 1.0
# Y_Sunday_Barbell Bench Press = 1.0
# Y_Sunday_Chest Press = 1.0
# Y_Sunday_Decline Dumbbell Bench Press = 1.0
# Y_Sunday_Decline Smith Machine Bench Press = 1.0
# Y_Sunday_Dumbbell Bench Press = 1.0
# Y_Sunday_Dumbbell Push-Up = 1.0
# Y_Sunday_Elevated Push-Up = 1.0
# Y_Sunday_Flat Bench Press = 1.0
# Y_Sunday_Incline Alternating Dumbbell Bench Press = 1.0
# Y_Sunday_Incline Barbell Bench Press = 1.0
# Y_Sunday_Incline Bench Press = 1.0
# Y_Sunday_Incline Dumbbell Bench Press = 1.0
# Y_Sunday_Incline Hammer Dumbbell Bench Press = 1.0
# Y_Sunday_Incline Single-Arm Dumbbell Bench Press = 1.0
# Y_Sunday_Incline Smith Machine Bench Press = 1.0
# Y_Sunday_Incline Twisting Dumbbell Bench Press = 1.0
# Y_Sunday_Kneeling Push-Up = 1.0
# Y_Sunday_Machine Bench Press = 1.0
# Y_Sunday_Machine Vertical Bench Press = 1.0
# Y_Sunday_Medicine Ball Crossover Push-Up = 1.0
# Y_Sunday_Push-Up = 1.0
# Y_Sunday_Single-Arm Dumbbell Bench Press = 1.0
# Y_Sunday_Smith Machine Bench Press = 1.0
# Y_Sunday_Twisting Dumbbell Bench Press = 1.0
# Y_Sunday_Wide-Grip Push-Up = 1.0
# Y_Sunday_Cable Crossover = 1.0
# Y_Sunday_Cable Fly = 1.0
# Y_Sunday_Decline Dumbbell Fly = 1.0
# Y_Sunday_Dumbbell Fly = 1.0
# Y_Sunday_High Cable Crossover = 1.0
# Y_Sunday_Incline Cable Fly = 1.0
# Y_Sunday_Incline Dumbbell Fly = 1.0
# Y_Sunday_Incline Twisting Dumbbell Fly = 1.0
# Y_Sunday_Low Cable Crossover = 1.0
# Y_Sunday_Pec Deck = 1.0
# Y_Sunday_Pec Deck Fly = 1.0
# Y_Sunday_Bent-Knee Single-Leg Hip Lift = 1.0
# Y_Sunday_Elevated Hip Lift = 1.0
# Y_Sunday_Elevated Single-Leg Hip Lift = 1.0
# Y_Sunday_Hip Lift = 1.0
# Y_Sunday_Single-Leg Hip Lift = 1.0
# Y_Sunday_Deadlift = 1.0
# Y_Sunday_Leg Curl = 1.0
# Y_Sunday_Lying Alternating Leg Curl = 1.0
# Y_Sunday_Lying Leg Curl = 1.0
# Y_Sunday_Lying Single-Leg Curl = 1.0
# Y_Sunday_Seated Leg Curl = 1.0
# Y_Sunday_Barbell Diagonal Lunge = 1.0
# Y_Sunday_Barbell Hack Squat = 1.0
# Y_Sunday_Barbell Lunge = 1.0
# Y_Sunday_Barbell Reverse Lunge = 1.0
# Y_Sunday_Barbell Side Lunge = 1.0
# Y_Sunday_Barbell Split Squat = 1.0
# Y_Sunday_Barbell Squat = 1.0
# Y_Sunday_Barbell Step-Up = 1.0
# Y_Sunday_Barbell Walking Lunge = 1.0
# Y_Sunday_Diagonal Lunge = 1.0
# Y_Sunday_Dumbbell Diagonal Lunge = 1.0
# Y_Sunday_Dumbbell Lunge = 1.0
# Y_Sunday_Dumbbell Reverse Lunge = 1.0
# Y_Sunday_Dumbbell Side Lunge = 1.0
# Y_Sunday_Dumbbell Split Squat = 1.0
# Y_Sunday_Dumbbell Squat = 1.0
# Y_Sunday_Dumbbell Step-Up = 1.0
# Y_Sunday_Dumbbell Walking Lunge = 1.0
# Y_Sunday_Forward Lunge = 1.0
# Y_Sunday_Lateral Barbell Squat = 1.0
# Y_Sunday_Lateral Barbell Step-Up = 1.0
# Y_Sunday_Lateral Squat = 1.0
# Y_Sunday_Lateral Step-Up = 1.0
# Y_Sunday_Leg Press = 1.0
# Y_Sunday_Lunge = 1.0
# Y_Sunday_Lying Machine Squat = 1.0
# Y_Sunday_Machine Hack Squat = 1.0
# Y_Sunday_Reverse Lunge = 1.0
# Y_Sunday_Single-Arm Barbell Side Squat = 1.0
# Y_Sunday_Single-Arm Dumbbell Side Squat = 1.0
# Y_Sunday_Single-Leg Barbell Squat = 1.0
# Y_Sunday_Single-Leg Box Squat = 1.0
# Y_Sunday_Single-Leg Dumbbell Box Squat = 1.0
# Y_Sunday_Single-Leg Dumbbell Squat = 1.0
# Y_Sunday_Single-Leg Squat = 1.0
# Y_Sunday_Smith Machine Squat = 1.0
# Y_Sunday_Split Squat = 1.0
# Y_Sunday_Step-Up = 1.0
# Y_Sunday_Walking Lunge = 1.0
# Y_Sunday_Alternating Leg Extension = 1.0
# Y_Sunday_Leg Extension = 1.0
# Y_Sunday_Single-Leg Extension = 1.0
# Y_Sunday_Alternating Superman = 1.0
# Y_Sunday_Back Raise = 1.0
# Y_Sunday_Quadruped Alternating Superman = 1.0
# Y_Sunday_Superman = 1.0
# Y_Sunday_Superman Hold = 1.0
# Y_Sunday_Arnold Dumbbell Press = 1.0
# Y_Sunday_Barbell Shoulder Press = 1.0
# Y_Sunday_Dumbbell Alternating Shoulder Press = 1.0
# Y_Sunday_Dumbbell Front Raise = 1.0
# Y_Sunday_Dumbbell Shoulder Press = 1.0
# Y_Sunday_Dumbbell Twisting Shoulder Press = 1.0
# Y_Sunday_Machine Shoulder Press = 1.0
# Y_Sunday_Seated Dumbbell Rear Delt Elbow Raise = 1.0
# Y_Sunday_Single-Arm Dumbbell Shoulder Press = 1.0
# Y_Sunday_Smith Machine Shoulder Press = 1.0
# Y_Sunday_Barbell Front Raise = 1.0
# Y_Sunday_Bent-Over Cable Rear Delt Raise = 1.0
# Y_Sunday_Bent-Over Dumbbell Rear Delt Raise = 1.0
# Y_Sunday_Cable Front Raise = 1.0
# Y_Sunday_Cable Lateral Raise = 1.0
# Y_Sunday_Dumbbell Lateral Raise = 1.0
# Y_Sunday_Front Plate Raise = 1.0
# Y_Sunday_Kneeling Single-Arm Cable Rear Delt Raise = 1.0
# Y_Sunday_Lying Dumbbell External Rotation = 1.0
# Y_Sunday_Lying Dumbbell Rear Delt Raise = 1.0
# Y_Sunday_Lying Single-Arm Dumbbell Rear Delt Raise = 1.0
# Y_Sunday_Pec Deck Real Delt Extensions = 1.0
# Y_Sunday_Reverse Incline Dumbbell Rear Delt Raise = 1.0
# Y_Sunday_Seated Dumbbell Rear Delt Raise = 1.0
# Y_Sunday_Single-Arm Cable Lateral Raise = 1.0
# Y_Sunday_Cable External Rotation = 1.0
# Y_Sunday_Close-Grip Bench Press = 1.0
# Y_Sunday_Forward Lean Dips = 1.0
# Y_Sunday_Assisted Dips = 1.0
# Y_Sunday_Bench Dips = 1.0
# Y_Sunday_Diamond Push-Up = 1.0
# Y_Sunday_Dips = 1.0
# Y_Sunday_Machine Dips = 1.0
# Y_Sunday_Decline Dumbbell Triceps Extension = 1.0
# Y_Sunday_Decline EZ-Bar Tricep Extension = 1.0
# Y_Sunday_Decline Single Dumbbell Triceps Extension = 1.0
# Y_Sunday_Decline Single-Arm Dumbbell Triceps Extension = 1.0
# Y_Sunday_Dumbbell Kickback = 1.0
# Y_Sunday_Incline EZ-Bar Tricep Extension = 1.0
# Y_Sunday_Kneeling Cable Triceps Extension = 1.0
# Y_Sunday_Leaning Overhead Tricep Extension = 1.0
# Y_Sunday_Low Cable Triceps Extension = 1.0
# Y_Sunday_Lying Cable Triceps Extension = 1.0
# Y_Sunday_Lying EZ-Bar Triceps Extension = 1.0
# Y_Sunday_Lying Overhead EZ-Bar Tricep Extension = 1.0
# Y_Sunday_Lying Reverse EZ-Bar Triceps Extension = 1.0
# Y_Sunday_Lying Single Dumbbell Triceps Extension = 1.0
# Y_Sunday_Lying Single-Arm Dumbbell Triceps Extension = 1.0
# Y_Sunday_Lying Tricep Extensions = 1.0
# Y_Sunday_Overhead Dumbbell Triceps Extension = 1.0
# Y_Sunday_Overhead EZ-Bar Triceps Extension = 1.0
# Y_Sunday_Overhead Rope Cable Tricep Extension = 1.0
# Y_Sunday_Overhead Single Dumbbell Tricep Extension = 1.0
# Y_Sunday_Overhead Single-Arm Cable Tricep Extension = 1.0
# Y_Sunday_Overhead Single-Arm Dumbbell Tricep Extension = 1.0
# Y_Sunday_Reverse Tricep Pushdown = 1.0
# Y_Sunday_Rope Triceps Pushdown = 1.0
# Y_Sunday_Single-Arm Towel Triceps Pushdown = 1.0
# Y_Sunday_Single-Arm Triceps Pushdown = 1.0
# Y_Sunday_Towel Triceps Pushdown = 1.0
# Y_Sunday_Tricep Extensions = 1.0
# Y_Sunday_Tricep Pushdown = 1.0
# Y_Sunday_Tricep Pushdown = 1.0
# Y_Sunday_V-Bar Tricep Pushdown = 1.0
# W_Monday_Race walking = 1.0
# W_Monday_Walking, under 2.0 mph, very slow = 1.0
# W_Monday_Walking 2.0 mph, slow = 1.0
# W_Monday_Walking 2.5 mph = 1.0
# W_Monday_Walking 3.0 mph, moderate = 1.0
# W_Monday_Walking 3.5 mph, brisk pace = 1.0
# W_Monday_Walking 3.5 mph, uphill = 1.0
# W_Monday_Walking 4.0 mph, very brisk = 1.0
# W_Monday_Walking 4.5 mph = 1.0
# W_Monday_Walking 5.0 mph = 1.0
# W_Monday_Stretching, hatha yoga = 1.0
# W_Monday_Mild stretching = 1.0
# W_Monday_Stair machine = 1.0
# W_Monday_Running, 5 mph (12 minute mile) = 1.0
# W_Monday_Running, 5.2 mph (11.5 minute mile) = 1.0
# W_Monday_Running, 6 mph (10 min mile) = 1.0
# W_Monday_Running, 6.7 mph (9 min mile) = 1.0
# W_Monday_Running, 7 mph (8.5 min mile) = 1.0
# W_Monday_Running, 7.5mph (8 min mile) = 1.0
# W_Monday_Running, 8 mph (7.5 min mile) = 1.0
# W_Monday_Running, 8.6 mph (7 min mile) = 1.0
# W_Monday_Running, general = 1.0
# W_Monday_Jumping rope, fast = 1.0
# W_Monday_Jumping rope, moderate = 1.0
# W_Monday_Jumping rope, slow = 1.0
# W_Monday_Cycling, mountain bike, bmx = 1.0
# W_Monday_Cycling, <10 mph, leisure bicycling = 1.0
# W_Monday_Cycling, 10-11.9 mph, light = 1.0
# W_Monday_Cycling, 12-13.9 mph, moderate = 1.0
# W_Monday_Cycling, 14-15.9 mph, vigorous = 1.0
# W_Monday_Cycling, 16-19 mph, very fast, racing = 1.0
# W_Monday_Stationary cycling, very light = 1.0
# W_Monday_Stationary cycling, light = 1.0
# W_Monday_Stationary cycling, moderate = 1.0
# W_Monday_Stationary cycling, vigorous = 1.0
# W_Monday_Stationary cycling, very vigorous = 1.0
# W_Monday_Circuit training, minimal rest = 1.0
# W_Monday_Aerobics, low impact = 1.0
# W_Monday_Aerobics, high impact = 1.0
# W_Monday_Aerobics, step aerobics = 1.0
# W_Monday_Aerobics, general = 1.0
# W_Thursday_Race walking = 1.0
# W_Thursday_Walking, under 2.0 mph, very slow = 1.0
# W_Thursday_Walking 2.0 mph, slow = 1.0
# W_Thursday_Walking 2.5 mph = 1.0
# W_Thursday_Walking 3.0 mph, moderate = 1.0
# W_Thursday_Walking 3.5 mph, brisk pace = 1.0
# W_Thursday_Walking 3.5 mph, uphill = 1.0
# W_Thursday_Walking 4.0 mph, very brisk = 1.0
# W_Thursday_Walking 4.5 mph = 1.0
# W_Thursday_Walking 5.0 mph = 1.0
# W_Thursday_Stretching, hatha yoga = 1.0
# W_Thursday_Mild stretching = 1.0
# W_Thursday_Stair machine = 1.0
# W_Thursday_Running, 5 mph (12 minute mile) = 1.0
# W_Thursday_Running, 5.2 mph (11.5 minute mile) = 1.0
# W_Thursday_Running, 6 mph (10 min mile) = 1.0
# W_Thursday_Running, 6.7 mph (9 min mile) = 1.0
# W_Thursday_Running, 7 mph (8.5 min mile) = 1.0
# W_Thursday_Running, 7.5mph (8 min mile) = 1.0
# W_Thursday_Running, 8 mph (7.5 min mile) = 1.0
# W_Thursday_Running, 8.6 mph (7 min mile) = 1.0
# W_Thursday_Running, general = 1.0
# W_Thursday_Jumping rope, fast = 1.0
# W_Thursday_Jumping rope, moderate = 1.0
# W_Thursday_Jumping rope, slow = 1.0
# W_Thursday_Cycling, mountain bike, bmx = 1.0
# W_Thursday_Cycling, <10 mph, leisure bicycling = 1.0
# W_Thursday_Cycling, 10-11.9 mph, light = 1.0
# W_Thursday_Cycling, 12-13.9 mph, moderate = 1.0
# W_Thursday_Cycling, 14-15.9 mph, vigorous = 1.0
# W_Thursday_Cycling, 16-19 mph, very fast, racing = 1.0
# W_Thursday_Stationary cycling, very light = 1.0
# W_Thursday_Stationary cycling, light = 1.0
# W_Thursday_Stationary cycling, moderate = 1.0
# W_Thursday_Stationary cycling, vigorous = 1.0
# W_Thursday_Stationary cycling, very vigorous = 1.0
# W_Thursday_Circuit training, minimal rest = 1.0
# W_Thursday_Aerobics, low impact = 1.0
# W_Thursday_Aerobics, high impact = 1.0
# W_Thursday_Aerobics, step aerobics = 1.0
# W_Thursday_Aerobics, general = 1.0
# W_Friday_Race walking = 1.0
# W_Friday_Walking, under 2.0 mph, very slow = 1.0
# W_Friday_Walking 2.0 mph, slow = 1.0
# W_Friday_Walking 2.5 mph = 1.0
# W_Friday_Walking 3.0 mph, moderate = 1.0
# W_Friday_Walking 3.5 mph, brisk pace = 1.0
# W_Friday_Walking 3.5 mph, uphill = 1.0
# W_Friday_Walking 4.0 mph, very brisk = 1.0
# W_Friday_Walking 4.5 mph = 1.0
# W_Friday_Walking 5.0 mph = 1.0
# W_Friday_Stretching, hatha yoga = 1.0
# W_Friday_Mild stretching = 1.0
# W_Friday_Stair machine = 1.0
# W_Friday_Running, 5 mph (12 minute mile) = 1.0
# W_Friday_Running, 5.2 mph (11.5 minute mile) = 1.0
# W_Friday_Running, 6 mph (10 min mile) = 1.0
# W_Friday_Running, 6.7 mph (9 min mile) = 1.0
# W_Friday_Running, 7 mph (8.5 min mile) = 1.0
# W_Friday_Running, 7.5mph (8 min mile) = 1.0
# W_Friday_Running, 8 mph (7.5 min mile) = 1.0
# W_Friday_Running, 8.6 mph (7 min mile) = 1.0
# W_Friday_Running, general = 1.0
# W_Friday_Jumping rope, fast = 1.0
# W_Friday_Jumping rope, moderate = 1.0
# W_Friday_Jumping rope, slow = 1.0
# W_Friday_Cycling, mountain bike, bmx = 1.0
# W_Friday_Cycling, <10 mph, leisure bicycling = 1.0
# W_Friday_Cycling, 10-11.9 mph, light = 1.0
# W_Friday_Cycling, 12-13.9 mph, moderate = 1.0
# W_Friday_Cycling, 14-15.9 mph, vigorous = 1.0
# W_Friday_Cycling, 16-19 mph, very fast, racing = 1.0
# W_Friday_Stationary cycling, very light = 1.0
# W_Friday_Stationary cycling, light = 1.0
# W_Friday_Stationary cycling, moderate = 1.0
# W_Friday_Stationary cycling, vigorous = 1.0
# W_Friday_Stationary cycling, very vigorous = 1.0
# W_Friday_Circuit training, minimal rest = 1.0
# W_Friday_Aerobics, low impact = 1.0
# W_Friday_Aerobics, high impact = 1.0
# W_Friday_Aerobics, step aerobics = 1.0
# W_Friday_Aerobics, general = 1.0
# W_Saturday_Race walking = 1.0
# W_Saturday_Walking, under 2.0 mph, very slow = 1.0
# W_Saturday_Walking 2.0 mph, slow = 1.0
# W_Saturday_Walking 2.5 mph = 1.0
# W_Saturday_Walking 3.0 mph, moderate = 1.0
# W_Saturday_Walking 3.5 mph, brisk pace = 1.0
# W_Saturday_Walking 3.5 mph, uphill = 1.0
# W_Saturday_Walking 4.0 mph, very brisk = 1.0
# W_Saturday_Walking 4.5 mph = 1.0
# W_Saturday_Walking 5.0 mph = 1.0
# W_Saturday_Stretching, hatha yoga = 1.0
# W_Saturday_Mild stretching = 1.0
# W_Saturday_Stair machine = 1.0
# W_Saturday_Running, 5 mph (12 minute mile) = 1.0
# W_Saturday_Running, 5.2 mph (11.5 minute mile) = 1.0
# W_Saturday_Running, 6 mph (10 min mile) = 1.0
# W_Saturday_Running, 6.7 mph (9 min mile) = 1.0
# W_Saturday_Running, 7 mph (8.5 min mile) = 1.0
# W_Saturday_Running, 7.5mph (8 min mile) = 1.0
# W_Saturday_Running, 8 mph (7.5 min mile) = 1.0
# W_Saturday_Running, 8.6 mph (7 min mile) = 1.0
# W_Saturday_Running, general = 1.0
# W_Saturday_Jumping rope, fast = 1.0
# W_Saturday_Jumping rope, moderate = 1.0
# W_Saturday_Jumping rope, slow = 1.0
# W_Saturday_Cycling, mountain bike, bmx = 1.0
# W_Saturday_Cycling, <10 mph, leisure bicycling = 1.0
# W_Saturday_Cycling, 10-11.9 mph, light = 1.0
# W_Saturday_Cycling, 12-13.9 mph, moderate = 1.0
# W_Saturday_Cycling, 14-15.9 mph, vigorous = 1.0
# W_Saturday_Cycling, 16-19 mph, very fast, racing = 1.0
# W_Saturday_Stationary cycling, very light = 1.0
# W_Saturday_Stationary cycling, light = 1.0
# W_Saturday_Stationary cycling, moderate = 1.0
# W_Saturday_Stationary cycling, vigorous = 1.0
# W_Saturday_Stationary cycling, very vigorous = 1.0
# W_Saturday_Circuit training, minimal rest = 1.0
# W_Saturday_Aerobics, low impact = 1.0
# W_Saturday_Aerobics, high impact = 1.0
# W_Saturday_Aerobics, step aerobics = 1.0
# W_Saturday_Aerobics, general = 1.0
